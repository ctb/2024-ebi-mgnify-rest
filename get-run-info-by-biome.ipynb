# %%
# %%file a.py
# Connection to MGnify API
from jsonapi_client import Session as APISession
from jsonapi_client import Modifier
import requests

# Dataframes and display
import pandas as pd

pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# Data transformation
from functools import reduce
from collections import defaultdict
# Out:
# Writing a.py

# %%
# %%file b.py
def get_all_biome_names():
    endpoint_name='biomes'
    r = requests.get(f"https://www.ebi.ac.uk/metagenomics/api/latest/{endpoint_name}")
    result = r.json()
    num_pages = result['meta']['pagination']['pages']

    xx = []
    for page in range(1, num_pages + 1):
        print(f'working on page: {page}')
        r = requests.get(f"https://www.ebi.ac.uk/metagenomics/api/latest/{endpoint_name}?page={page}")
        xx.append(r.json())

    print(f'got {len(xx)}')
    return xx

z = get_all_biome_names()
# Out:
# Writing b.py

# %%
# %%file c.py
all_biomes=[]
for result in z:
    data = result['data']
    #print(data)
    for record in data:
        print(record['id'])
        print(record['attributes']['samples-count'])
        all_biomes.append((record['id'],record['attributes']['samples-count']))

orig_all_biomes = all_biomes
# Out:
# Writing c.py

# %%
all_biomes = orig_all_biomes
all_biomes.sort(key=lambda x: x[1])
print("all:", len(all_biomes))
all_biomes = [ (x, y) for (x, y) in all_biomes if y > 0 ]
print("0-filtered:", len(all_biomes))
all_biomes = [ (x, y) for (x, y) in all_biomes if y >= 10 ]
print("10-filtered:", len(all_biomes))
all_biomes = [ (x, y) for (x, y) in all_biomes if y >= 50 ]
print("50-filtered:", len(all_biomes))

all_biomes = [ (x, y) for (x, y) in all_biomes if x.count(':') == 3 ]
print("hierarchy filtered:", len(all_biomes))

all_biomes[:50]
# Out:
# all: 475
# 0-filtered: 289
# 10-filtered: 242
# 50-filtered: 196
# hierarchy filtered: 44
# [('root:Host-associated:Fish:Skin', 51),
#  ('root:Environmental:Terrestrial:Agricultural field', 52),
#  ('root:Engineered:Bioremediation:Persistent organic pollutants (POP)', 53),
#  ('root:Engineered:Modeled:Simulated communities (DNA mixture)', 59),
#  ('root:Engineered:Bioremediation:Hydrocarbon', 65),
#  ('root:Engineered:Modeled:Simulated communities (sequence read mixture)', 67),
#  ('root:Host-associated:Birds:Respiratory system', 67),
#  ('root:Environmental:Aquatic:Estuary', 70),
#  ('root:Environmental:Aquatic:Non-marine Saline and Alkaline', 71),
#  ('root:Host-associated:Mammals:Milk', 72),
#  ('root:Engineered:Lab enrichment:Defined media', 80),
#  ('root:Environmental:Terrestrial:Geologic', 85),
#  ('root:Host-associated:Human:Respiratory system', 105),
#  ('root:Engineered:Biogas plant:Wet fermentation', 111),
#  ('root:Engineered:Solid waste:Composting', 159),
#  ('root:Host-associated:Algae:Brown Algae', 179),
#  ('root:Host-associated:Animal:Digestive system', 233),
#  ('root:Engineered:Food production:Fermented beverages', 270),
#  ('root:Engineered:Wastewater:Industrial wastewater', 306),
#  ('root:Host-associated:Plants:Rhizome', 370),
#  ('root:Engineered:Food production:Fermented vegetables', 395),
#  ('root:Environmental:Aquatic:Freshwater', 413),
#  ('root:Engineered:Bioreactor:Continuous culture', 648),
#  ('root:Engineered:Modeled:Simulated communities (microbial mixture)', 656),
#  ('root:Environmental:Aquatic:Thermal springs', 704),
#  ('root:Host-associated:Fish:Digestive system', 704),
#  ('root:Host-associated:Mollusca:Digestive system', 819),
#  ('root:Environmental:Terrestrial:Deep subsurface', 829),
#  ('root:Environmental:Aquatic:Sediment', 870),
#  ('root:Engineered:Wastewater:Water and sludge', 958),
#  ('root:Host-associated:Mammals:Skin', 1056),
#  ('root:Host-associated:Mammals:Respiratory system', 1088),
#  ('root:Host-associated:Insecta:Digestive system', 1220),
#  ('root:Engineered:Wastewater:Activated Sludge', 1252),
#  ('root:Host-associated:Mammals:Gastrointestinal tract', 1591),
#  ('root:Engineered:Food production:Dairy products', 1829),
#  ('root:Host-associated:Plants:Phylloplane', 1894),
#  ('root:Host-associated:Birds:Digestive system', 2034),
#  ('root:Host-associated:Plants:Rhizosphere', 5268),
#  ('root:Host-associated:Human:Skin', 11407),
#  ('root:Host-associated:Mammals:Digestive system', 12258),
#  ('root:Environmental:Terrestrial:Soil', 13041),
#  ('root:Host-associated:Human:Digestive system', 20067),
#  ('root:Environmental:Aquatic:Marine', 20295)]

# %%
# %%file d.py
def get_samples_for_biome(biome):
    endpoint_name='biomes'
    r = requests.get(f"https://www.ebi.ac.uk/metagenomics/api/latest/{endpoint_name}/{biome}/samples")
    result = r.json()
    num_pages = result['meta']['pagination']['pages']

    xx = []
    for page in range(1, num_pages + 1):
        print(f'working on page: {page} of {num_pages}')
        r = requests.get(f"https://www.ebi.ac.uk/metagenomics/api/latest/{endpoint_name}/{biome}/samples?page={page}")
        xx.append(r.json())

    print(f'got {len(xx)} pages')
    return xx

#biome_name = all_biomes[0][0]
#samples_from_biomes = get_samples_for_biome(biome_name)
# Out:
# Writing d.py

# %%
# %%file e.py
def get_runs_from_samples(samples_data):
    xx = []
    for item in samples_data:
        for item2 in item['data']:
            xx.append(item2['relationships']['runs']['links']['related'])
    return xx

#runs_from_samples = get_runs_from_samples(samples_from_biomes)
# Out:
# Writing e.py

# %%
#runs_from_samples
# Out:
# ['https://www.ebi.ac.uk/metagenomics/api/v1/samples/SRS9995124/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS5886824/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS5886826/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS5886825/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS5886828/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS5886827/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS4409919/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS4413232/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS4413234/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS4413248/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS4413260/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS4413262/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS4413265/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS4413276/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS4413278/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS4413282/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS4413284/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS4413281/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/SRS1379411/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS3036499/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS3037841/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS3037840/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS3040056/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS3040055/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS3104179/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/SRS475645/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/SRS475671/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/SRS475948/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/SRS476343/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/SRS476788/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/SRS463865/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/SRS470596/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/SRS470597/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/SRS470598/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/SRS470599/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/SRS470618/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/SRS470620/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/SRS470621/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/SRS470623/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/SRS475486/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS696577/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS696578/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS696579/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS696580/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/SRS1414572/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/SRS948184/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/SRS948190/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/SRS3007729/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/SRS3007730/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/SRS3007731/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/SRS3007732/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/SRS3007910/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/SRS3007911/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS756985/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS756986/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS756987/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS756988/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS756989/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS756990/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS756991/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS756992/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS758253/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS719958/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS719959/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS719960/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS719961/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS719962/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS719963/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS719964/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS719965/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS719966/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS719967/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS719968/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS719969/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS719970/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS719971/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS529626/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS529627/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS1459885/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS1459886/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS1459887/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS1459888/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS1459889/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS1459890/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS1455389/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS1455390/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS1455391/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/SRS464643/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/SRS478661/runs']

# %%
# %%file g.py
def get_run_info_for_runs(run_urls):
    zz = []
    for n, run_url in enumerate(run_urls):
        print(f"{n + 1} of {len(run_urls)}")
        r = requests.get(run_url)
        result = r.json()
        num_pages = result['meta']['pagination']['pages']
        if num_pages == 1:
            zz.append(result)
        else:
            for page in range(1, num_pages + 1):
                print(f'working on page: {page} of {num_pages} for run URL {run_url}')        
                r = requests.get(run_url + f"?page={page}")
                zz.append(r.json)

    return zz

#run_info = get_run_info_for_runs(runs_from_samples)
# Out:
# Writing g.py

# %%
len(run_info)
# Out:
# 89

# %%
run_info[0]['data'][0]['attributes']
# Out:
# {'experiment-type': 'metagenomic',
#  'is-private': False,
#  'accession': 'SRR15691272',
#  'secondary-accession': 'SRR15691272',
#  'ena-study-accession': None,
#  'instrument-platform': 'ILLUMINA',
#  'instrument-model': 'Illumina NovaSeq 6000'}

# %%
for ri in run_info:
    for item in ri['data']:
        attr = item.get('attributes')
        print(attr['accession'], attr['experiment-type'], attr['instrument-platform'], attr['instrument-model'])
# Out:
# SRR15691272 metagenomic ILLUMINA Illumina NovaSeq 6000
# ERR5416478 unknown ILLUMINA Illumina HiSeq 3000
# ERR5416927 unknown ILLUMINA Illumina HiSeq 3000
# ERR5416479 unknown ILLUMINA Illumina HiSeq 3000
# ERR5416480 unknown ILLUMINA Illumina HiSeq 3000
# ERR5416520 unknown ILLUMINA Illumina HiSeq 3000
# ERR4007995 amplicon ILLUMINA Illumina MiSeq
# ERR4008002 amplicon ILLUMINA Illumina MiSeq
# ERR4008004 amplicon ILLUMINA Illumina MiSeq
# ERR4008006 amplicon ILLUMINA Illumina MiSeq
# ERR4008008 amplicon ILLUMINA Illumina MiSeq
# ERR4008009 amplicon ILLUMINA Illumina MiSeq
# ERR4008051 amplicon ILLUMINA Illumina MiSeq
# ERR4008052 amplicon ILLUMINA Illumina MiSeq
# ERR4008054 amplicon ILLUMINA Illumina MiSeq
# ERR4008058 amplicon ILLUMINA Illumina MiSeq
# ERR4008061 amplicon ILLUMINA Illumina MiSeq
# ERR4008062 amplicon ILLUMINA Illumina MiSeq
# SRR3341855 metagenomic ILLUMINA Illumina Genome Analyzer IIx
# SRR3341747 metagenomic ILLUMINA Illumina Genome Analyzer IIx
# SRR3341746 metagenomic ILLUMINA Illumina Genome Analyzer IIx
# ERR3079486 metagenomic ILLUMINA Illumina MiSeq
# ERR3085930 metagenomic ILLUMINA Illumina MiSeq
# ERR3085921 metagenomic ILLUMINA Illumina MiSeq
# ERR3083899 metagenomic ILLUMINA Illumina MiSeq
# ERR3082345 metagenomic ILLUMINA Illumina MiSeq
# ERR3132464 metagenomic ILLUMINA Illumina MiSeq
# ERR3132463 metagenomic ILLUMINA Illumina MiSeq
# ERR3132462 metagenomic ILLUMINA Illumina MiSeq
# SRR1171844 amplicon LS454 454 GS FLX Titanium
# SRR1171846 amplicon LS454 454 GS FLX Titanium
# SRR1171848 amplicon LS454 454 GS FLX Titanium
# SRR1171849 amplicon LS454 454 GS FLX Titanium
# SRR1171851 amplicon LS454 454 GS FLX Titanium
# SRR952665 amplicon LS454 454 GS FLX Titanium
# SRR952911 amplicon LS454 454 GS FLX+
# SRR952912 amplicon LS454 454 GS FLX Titanium
# SRR952913 amplicon LS454 454 GS FLX Titanium
# SRR952914 amplicon LS454 454 GS FLX Titanium
# SRR952915 amplicon LS454 454 GS FLX Titanium
# SRR952916 amplicon LS454 454 GS FLX Titanium
# SRR952917 amplicon LS454 454 GS FLX Titanium
# SRR952918 amplicon LS454 454 GS FLX Titanium
# SRR961678 amplicon LS454 454 GS FLX Titanium
# ERR841769 amplicon LS454 454 GS FLX+
# ERR841770 amplicon LS454 454 GS FLX+
# ERR841771 amplicon LS454 454 GS FLX+
# ERR841772 amplicon LS454 454 GS FLX+
# SRR3480638 amplicon LS454 454 GS FLX Titanium
# SRR3453161 amplicon LS454 454 GS FLX Titanium
# SRR2043654 amplicon ILLUMINA Illumina MiSeq
# SRR2043661 amplicon ILLUMINA Illumina MiSeq
# SRR6792326 amplicon ION_TORRENT Ion Torrent PGM
# SRR6792325 amplicon ION_TORRENT Ion Torrent PGM
# SRR6792327 amplicon ION_TORRENT Ion Torrent PGM
# SRR6792323 amplicon ION_TORRENT Ion Torrent PGM
# SRR6792328 amplicon ION_TORRENT Ion Torrent PGM
# SRR6792324 amplicon ION_TORRENT Ion Torrent PGM
# ERR921017 amplicon
# ERR921018 amplicon
# ERR921019 amplicon
# ERR921020 amplicon
# ERR921021 amplicon
# ERR921022 amplicon
# ERR921023 amplicon
# ERR921024 amplicon
# ERR921728 amplicon
# ERR876028 amplicon
# ERR876029 amplicon
# ERR876030 amplicon
# ERR876031 amplicon
# ERR876032 amplicon
# ERR876033 amplicon
# ERR876034 amplicon
# ERR876035 amplicon
# ERR876036 amplicon
# ERR876037 amplicon
# ERR876038 amplicon
# ERR876039 amplicon
# ERR876040 amplicon
# ERR876041 amplicon
# ERR580982 amplicon
# ERR580981 amplicon
# ERR580980 amplicon
# ERR580979 amplicon
# ERR580978 amplicon
# ERR580977 amplicon
# ERR580988 amplicon
# ERR580987 amplicon
# ERR580986 amplicon
# ERR580985 amplicon
# ERR580984 amplicon
# ERR580983 amplicon
# ERR1742997 metagenomic
# ERR1742998 metagenomic
# ERR1742999 metagenomic
# ERR1743000 metagenomic
# ERR1743001 metagenomic
# ERR1743002 metagenomic
# ERR1739731 metagenomic
# ERR1739732 metagenomic
# ERR1739733 metagenomic
# SRR944625 metagenomic
# SRR979792 metagenomic

# %%
# %%file h.py
samples_by_biome = {}
for n, (biome_name, count) in enumerate(all_biomes):
    if n > 10:
        print(f'stopping at {n} for testing purposes')
        break
    print(f"getting: {biome_name} ({n + 1} of {len(all_biomes)})")
    samples_by_biome[biome_name] = get_samples_for_biome(biome_name)
    print(f"got: {len(samples_by_biome[biome_name])}")
# Out:
# Writing h.py

# %%
# TODO: dump to file!
# - [x] get only level 2 or level 3 biomes, since presumably the hierarchy is inclusive :sweat:

# %%
del runs_by_biome['root:Engineered:Modeled:Simulated communities (sequence read mixture)']

# %%
#runs_by_biome = defaultdict(list)
for biome_name, samples_vv in samples_by_biome.items():
    if biome_name in runs_by_biome:
        print(f'skipping {biome_name} - already present.')
        continue
    zz = get_runs_from_samples(samples_vv)
    runs_by_biome[biome_name].extend(zz)
# Out:
# skipping root:Host-associated:Fish:Skin - already present.
# skipping root:Environmental:Terrestrial:Agricultural field - already present.
# skipping root:Engineered:Bioremediation:Persistent organic pollutants (POP) - already present.
# skipping root:Engineered:Modeled:Simulated communities (DNA mixture) - already present.
# skipping root:Engineered:Bioremediation:Hydrocarbon - already present.
# skipping root:Host-associated:Birds:Respiratory system - already present.
# skipping root:Environmental:Aquatic:Estuary - already present.
# skipping root:Environmental:Aquatic:Non-marine Saline and Alkaline - already present.
# skipping root:Host-associated:Mammals:Milk - already present.
# skipping root:Engineered:Lab enrichment:Defined media - already present.

# %%
list(runs_by_biome.items())[:5]
# Out:
# [('root:Host-associated:Fish:Skin',
#   ['https://www.ebi.ac.uk/metagenomics/api/v1/samples/SRS
https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS956386/runs'])]

# %%
del runinfo_by_biome['root:Engineered:Modeled:Simulated communities (sequence read mixture)']

# %%
# %%file m.py
#runinfo_by_biome = defaultdict(list)
for biome_name, runlist in runs_by_biome.items():
    if biome_name in runinfo_by_biome:
        print(f"skipping {biome_name} - already present.")
        continue
    print(f"working on {biome_name} - {len(runlist)} runs")
    zz = get_run_info_for_runs(runlist)
    runinfo_by_biome[biome_name] = zz
# Out:
# Writing m.py

# %%
for biome_name, run_info in runinfo_by_biome.items():
    for n, ri in enumerate(run_info):
        try:
            for item in ri['data']:
                attr = item.get('attributes')
                print(biome_name, attr['accession'], attr['experiment-type'], attr['instrument-platform'], attr['instrument-model'])
        except TypeError:
            print(f'ERROR: biome {biome_name}, entry {n}')
            raise
# Out:
# root:Host-associated:Fish:Skin SRR3236773 amplicon ILLUMINA Illumina MiSeq
# root:Host-associated:Fish:Skin SRR3236772 amplicon ILLUMINA Illumina MiSeq
# root:Host-associated:Fish:Skin SRR3236767 amplicon ILLUMINA Illumina MiSeq
# root:Host-associated:Fish:Skin SRR3236766 amplicon ILLUMINA Illumina MiSeq
# root:Host-associated:Fish:Skin SRR3236765 amplicon ILLUMINA Illumina MiSeq
# root:Host-associated:Fish:Skin ERR2754619 amplicon PACBIO_SMRT Sequel
# root:Host-associated:Fish:Skin ERR2754620 amplicon PACBIO_SMRT Sequel
# root:Host-associated:Fish:Skin ERR2754621 amplicon PACBIO_SMRT Sequel
# root:Host-associated:Fish:Skin ERR2754622 amplicon PACBIO_SMRT Sequel
# root:Host-associated:Fish:Skin ERR2754623 amplicon PACBIO_SMRT Sequel
# root:Host-associated:Fish:Skin ERR2754624 amplicon PACBIO_SMRT Sequel
# root:Host-associated:Fish:Skin ERR2754625 amplicon PACBIO_SMRT Sequel
# root:Host-associated:Fish:Skin ERR2754626 amplicon PACBIO_SMRT Sequel
# root:Host-associated:Fish:Skin ERR2754627 amplicon PACBIO_SMRT Sequel
# root:Host-associated:Fish:Skin ERR2754628 amplicon PACBIO_SMRT Sequel
# root:Host-associated:Fish:Skin ERR2754629 amplicon PACBIO_SMRT Sequel
# root:Host-associated:Fish:Skin ERR2754630 amplicon PACBIO_SMRT Sequel
# root:Host-associated:Fish:Skin ERR2754631 amplicon PACBIO_SMRT Sequel
# root:Host-associated:Fish:Skin ERR2754632 amplicon PACBIO_SMRT Sequel
# root:Host-associated:Fish:Skin ERR2754633 amplicon PACBIO_SMRT Sequel
# root:Host-associated:Fish:Skin ERR2754634 amplicon PACBIO_SMRT Sequel
# root:Host-associated:Fish:Skin ERR2754635 amplicon PACBIO_SMRT Sequel
# root:Host-associated:Fish:Skin ERR2754636 amplicon PACBIO_SMRT Sequel
# root:Host-associated:Fish:Skin ERR2754637 amplicon PACBIO_SMRT Sequel
# root:Host-associated:Fish:Skin ERR2754638 amplicon PACBIO_SMRT Sequel
# root:Host-associated:Fish:Skin ERR2754639 amplicon PACBIO_SMRT Sequel
# root:Host-associated:Fish:Skin ERR2754640 amplicon PACBIO_SMRT Sequel
# root:Host-associated:Fish:Skin ERR2754641 amplicon PACBIO_SMRT Sequel
# root:Host-associated:Fish:Skin ERR2754642 amplicon PACBIO_SMRT Sequel
# root:Host-associated:Fish:Skin ERR2754643 amplicon PACBIO_SMRT Sequel
# root:Host-associated:Fish:Skin ERR2754644 amplicon PACBIO_SMRT Sequel
# root:Host-associated:Fish:Skin ERR2754645 amplicon PACBIO_SMRT Sequel
# root:Host-associated:Fish:Skin ERR2754646 amplicon PACBIO_SMRT Sequel
# root:Host-associated:Fish:Skin ERR2754647 amplicon PACBIO_SMRT Sequel
# root:Host-associated:Fish:Skin ERR2754648 amplicon PACBIO_SMRT Sequel
# root:Host-associated:Fish:Skin ERR2754649 amplicon PACBIO_SMRT Sequel
# root:Host-associated:Fish:Skin ERR2754650 amplicon PACBIO_SMRT Sequel
# root:Host-associated:Fish:Skin ERR2754651 amplicon PACBIO_SMRT Sequel
# root:Host-associated:Fish:Skin ERR2754652 amplicon PACBIO_SMRT Sequel
# root:Host-associated:Fish:Skin ERR2754653 amplicon PACBIO_SMRT Sequel
# root:Host-associated:Fish:Skin ERR2754654 amplicon PACBIO_SMRT Sequel
# root:Host-associated:Fish:Skin ERR2754655 amplicon PACBIO_SMRT Sequel
# root:Host-associated:Fish:Skin ERR2754681 amplicon PACBIO_SMRT Sequel
# root:Host-associated:Fish:Skin ERR2754682 amplicon PACBIO_SMRT Sequel
# root:Host-associated:Fish:Skin ERR2754683 amplicon PACBIO_SMRT Sequel
# root:Host-associated:Fish:Skin ERR2754684 amplicon PACBIO_SMRT Sequel
# root:Host-associated:Fish:Skin ERR1840888 metagenomic
# root:Host-associated:Fish:Skin ERR1840889 metagenomic
# root:Host-associated:Fish:Skin ERR1840890 metagenomic
# root:Host-associated:Fish:Skin ERR1840891 metagenomic
# root:Host-associated:Fish:Skin ERR1840887 metagenomic
# root:Environmental:Terrestrial:Agricultural field ERR1413969 metagenomic
# root:Environmental:Terrestrial:Agricultural field ERR1413970 metagenomic
# root:Environmental:Terrestrial:Agricultural field ERR1413971 metagenomic
# root:Environmental:Terrestrial:Agricultural field ERR1413972 metagenomic
# root:Environmental:Terrestrial:Agricultural field ERR1413973 metagenomic
# root:Environmental:Terrestrial:Agricultural field ERR1413974 metagenomic
# root:Environmental:Terrestrial:Agricultural field ERR1413975 metagenomic
# root:Environmental:Terrestrial:Agricultural field ERR1413943 metagenomic
# root:Environmental:Terrestrial:Agricultural field ERR1413944 metagenomic
# root:Environmental:Terrestrial:Agricultural field ERR1413945 metagenomic
# root:Environmental:Terrestrial:Agricultural field ERR1413946 metagenomic
# root:Environmental:Terrestrial:Agricultural field ERR1413947 metagenomic
# root:Environmental:Terrestrial:Agricultural field ERR1413948 metagenomic
# root:Environmental:Terrestrial:Agricultural field ERR1413949 metagenomic
# root:Environmental:Terrestrial:Agricultural field ERR1413950 metagenomic
# root:Environmental:Terrestrial:Agricultural field ERR1413951 metagenomic
# root:Environmental:Terrestrial:Agricultural field ERR1413952 metagenomic
# root:Environmental:Terrestrial:Agricultural field ERR1413953 metagenomic
# root:Environmental:Terrestrial:Agricultural field ERR1413954 metagenomic
# root:Environmental:Terrestrial:Agricultural field ERR1413955 metagenomic
# root:Environmental:Terrestrial:Agricultural field ERR1413956 metagenomic
# root:Environmental:Terrestrial:Agricultural field ERR1413957 metagenomic
# root:Environmental:Terrestrial:Agricultural field ERR1413958 metagenomic
# root:Environmental:Terrestrial:Agricultural field ERR1413959 metagenomic
# root:Environmental:Terrestrial:Agricultural field ERR1413960 metagenomic
# root:Environmental:Terrestrial:Agricultural field ERR1413961 metagenomic
# root:Environmental:Terrestrial:Agricultural field ERR1413962 metagenomic
# root:Environmental:Terrestrial:Agricultural field ERR1413963 metagenomic
# root:Environmental:Terrestrial:Agricultural field ERR1413964 metagenomic
# root:Environmental:Terrestrial:Agricultural field ERR1413965 metagenomic
# root:Environmental:Terrestrial:Agricultural field ERR1413966 metagenomic
# root:Environmental:Terrestrial:Agricultural field ERR1413967 metagenomic
# root:Environmental:Terrestrial:Agricultural field ERR1413968 metagenomic
# root:Environmental:Terrestrial:Agricultural field ERR1413924 metagenomic
# root:Environmental:Terrestrial:Agricultural field ERR1413925 metagenomic
# root:Environmental:Terrestrial:Agricultural field ERR1413926 metagenomic
# root:Environmental:Terrestrial:Agricultural field ERR1413927 metagenomic
# root:Environmental:Terrestrial:Agricultural field ERR1413928 metagenomic
# root:Environmental:Terrestrial:Agricultural field ERR1413929 metagenomic
# root:Environmental:Terrestrial:Agricultural field ERR1413930 metagenomic
# root:Environmental:Terrestrial:Agricultural field ERR1413931 metagenomic
# root:Environmental:Terrestrial:Agricultural field ERR1413932 metagenomic
# root:Environmental:Terrestrial:Agricultural field ERR1413933 metagenomic
# root:Environmental:Terrestrial:Agricultural field ERR1413934 metagenomic
# root:Environmental:Terrestrial:Agricultural field ERR1413935 metagenomic
# root:Environmental:Terrestrial:Agricultural field ERR1413936 metagenomic
# root:Environmental:Terrestrial:Agricultural field ERR1413937 metagenomic
# root:Environmental:Terrestrial:Agricultural field ERR1413938 metagenomic
# root:Environmental:Terrestrial:Agricultural field ERR1413939 metagenomic
# root:Environmental:Terrestrial:Agricultural field ERR1413940 metagenomic
# root:Environmental:Terrestrial:Agricultural field ERR1413941 metagenomic
# root:Environmental:Terrestrial:Agricultural field ERR1413942 metagenomic
# root:Engineered:Bioremediation:Persistent organic pollutants (POP) ERR2729623 amplicon ILLUMINA Illumina MiSeq
# root:Engineered:Bioremediation:Persistent organic pollutants (POP) ERR2729624 amplicon ILLUMINA Illumina MiSeq
# root:Engineered:Bioremediation:Persistent organic pollutants (POP) ERR2729625 amplicon ILLUMINA Illumina MiSeq
# root:Engineered:Bioremediation:Persistent organic pollutants (POP) ERR2729626 amplicon ILLUMINA Illumina MiSeq
# root:Engineered:Bioremediation:Persistent organic pollutants (POP) ERR2729627 amplicon ILLUMINA Illumina MiSeq
# root:Engineered:Bioremediation:Persistent organic pollutants (POP) ERR2729628 amplicon ILLUMINA Illumina MiSeq
# root:Engineered:Bioremediation:Persistent organic pollutants (POP) ERR2729629 amplicon ILLUMINA Illumina MiSeq
# root:Engineered:Bioremediation:Persistent organic pollutants (POP) ERR2729630 amplicon ILLUMINA Illumina MiSeq
# root:Engineered:Bioremediation:Persistent organic pollutants (POP) ERR2729631 amplicon ILLUMINA Illumina MiSeq
# root:Engineered:Bioremediation:Persistent organic pollutants (POP) ERR2729632 amplicon ILLUMINA Illumina MiSeq
# root:Engineered:Bioremediation:Persistent organic pollutants (POP) ERR2729633 amplicon ILLUMINA Illumina MiSeq
# root:Engineered:Bioremediation:Persistent organic pollutants (POP) ERR2729634 amplicon ILLUMINA Illumina MiSeq
# root:Engineered:Bioremediation:Persistent organic pollutants (POP) ERR2729635 amplicon ILLUMINA Illumina MiSeq
# root:Engineered:Bioremediation:Persistent organic pollutants (POP) ERR2729636 amplicon ILLUMINA Illumina MiSeq
# root:Engineered:Bioremediation:Persistent organic pollutants (POP) ERR2729637 amplicon ILLUMINA Illumina MiSeq
# root:Engineered:Bioremediation:Persistent organic pollutants (POP) ERR2729638 amplicon ILLUMINA Illumina MiSeq
# root:Engineered:Bioremediation:Persistent organic pollutants (POP) ERR2729639 amplicon ILLUMINA Illumina MiSeq
# root:Engineered:Bioremediation:Persistent organic pollutants (POP) ERR2729640 amplicon ILLUMINA Illumina MiSeq
# root:Engineered:Bioremediation:Persistent organic pollutants (POP) ERR2729641 amplicon ILLUMINA Illumina MiSeq
# root:Engineered:Bioremediation:Persistent organic pollutants (POP) ERR2729642 amplicon ILLUMINA Illumina MiSeq
# root:Engineered:Bioremediation:Persistent organic pollutants (POP) ERR2729643 amplicon ILLUMINA Illumina MiSeq
# root:Engineered:Bioremediation:Persistent organic pollutants (POP) ERR2729644 amplicon ILLUMINA Illumina MiSeq
# root:Engineered:Bioremediation:Persistent organic pollutants (POP) ERR2729645 amplicon ILLUMINA Illumina MiSeq
# root:Engineered:Bioremediation:Persistent organic pollutants (POP) ERR2729646 amplicon ILLUMINA Illumina MiSeq
# root:Engineered:Bioremediation:Persistent organic pollutants (POP) ERR2729647 amplicon ILLUMINA Illumina MiSeq
# root:Engineered:Bioremediation:Persistent organic pollutants (POP) ERR2729648 amplicon ILLUMINA Illumina MiSeq
# root:Engineered:Bioremediation:Persistent organic pollutants (POP) ERR2729649 amplicon ILLUMINA Illumina MiSeq
# root:Engineered:Bioremediation:Persistent organic pollutants (POP) ERR2729650 amplicon ILLUMINA Illumina MiSeq
# root:Engineered:Bioremediation:Persistent organic pollutants (POP) ERR2729651 amplicon ILLUMINA Illumina MiSeq
# root:Engineered:Bioremediation:Persistent organic pollutants (POP) ERR2729652 amplicon ILLUMINA Illumina MiSeq
# root:Engineered:Bioremediation:Persistent organic pollutants (POP) ERR2729653 amplicon ILLUMINA Illumina MiSeq
# root:Engineered:Bioremediation:Persistent organic pollutants (POP) ERR2729654 amplicon ILLUMINA Illumina MiSeq
# root:Engineered:Bioremediation:Persistent organic pollutants (POP) ERR2729655 amplicon ILLUMINA Illumina MiSeq
# root:Engineered:Bioremediation:Persistent organic pollutants (POP) ERR2729656 amplicon ILLUMINA Illumina MiSeq
# root:Engineered:Bioremediation:Persistent organic pollutants (POP) ERR2729657 amplicon ILLUMINA Illumina MiSeq
# root:Engineered:Bioremediation:Persistent organic pollutants (POP) ERR2729658 amplicon ILLUMINA Illumina MiSeq
# root:Engineered:Bioremediation:Persistent organic pollutants (POP) ERR2729659 amplicon ILLUMINA Illumina MiSeq
# root:Engineered:Bioremediation:Persistent organic pollutants (POP) ERR2729660 amplicon ILLUMINA Illumina MiSeq
# root:Engineered:Bioremediation:Persistent organic pollutants (POP) ERR2729661 amplicon ILLUMINA Illumina MiSeq
# root:Engineered:Bioremediation:Persistent organic pollutants (POP) ERR2729662 amplicon ILLUMINA Illumina MiSeq
# root:Engineered:Bioremediation:Persistent organic pollutants (POP) ERR2729663 amplicon ILLUMINA Illumina MiSeq
# root:Engineered:Bioremediation:Persistent organic pollutants (POP) ERR2729664 amplicon ILLUMINA Illumina MiSeq
# root:Engineered:Bioremediation:Persistent organic pollutants (POP) ERR2729665 amplicon ILLUMINA Illumina MiSeq
# root:Engineered:Bioremediation:Persistent organic pollutants (POP) ERR2729666 amplicon ILLUMINA Illumina MiSeq
# root:Engineered:Bioremediation:Persistent organic pollutants (POP) ERR2729667 amplicon ILLUMINA Illumina MiSeq
# root:Engineered:Bioremediation:Persistent organic pollutants (POP) ERR2729668 amplicon ILLUMINA Illumina MiSeq
# root:Engineered:Bioremediation:Persistent organic pollutants (POP) ERR2729669 amplicon ILLUMINA Illumina MiSeq
# root:Engineered:Bioremediation:Persistent organic pollutants (POP) ERR2729670 amplicon ILLUMINA Illumina MiSeq
# root:Engineered:Bioremediation:Persistent organic pollutants (POP) ERR2729671 amplicon ILLUMINA Illumina MiSeq
# root:Engineered:Bioremediation:Persistent organic pollutants (POP) ERR2729672 amplicon ILLUMINA Illumina MiSeq
# root:Engineered:Bioremediation:Persistent organic pollutants (POP) ERR579992 amplicon
# root:Engineered:Bioremediation:Persistent organic pollutants (POP) ERR579993 amplicon
# root:Engineered:Bioremediation:Persistent organic pollutants (POP) ERR579994 amplicon
# root:Engineered:Modeled:Simulated communities (DNA mixture) ERR1898437 metagenomic
# root:Engineered:Modeled:Simulated communities (DNA mixture) ERR1898438 metagenomic
# root:Engineered:Modeled:Simulated communities (DNA mixture) ERR1898439 metagenomic
# root:Engineered:Modeled:Simulated communities (DNA mixture) ERR1898440 metagenomic
# root:Engineered:Modeled:Simulated communities (DNA mixture) ERR1713484 metagenomic
# root:Engineered:Modeled:Simulated communities (DNA mixture) ERR1713485 metagenomic
# root:Engineered:Modeled:Simulated communities (DNA mixture) ERR1713487 metagenomic
# root:Engineered:Modeled:Simulated communities (DNA mixture) ERR1713488 metagenomic
# root:Engineered:Modeled:Simulated communities (DNA mixture) ERR1713489 metagenomic
# root:Engineered:Modeled:Simulated communities (DNA mixture) ERR1713490 metagenomic
# root:Engineered:Modeled:Simulated communities (DNA mixture) ERR1713483 metagenomic
# root:Engineered:Modeled:Simulated communities (DNA mixture) ERR1713486 metagenomic
# root:Engineered:Modeled:Simulated communities (DNA mixture) SRR606363 amplicon
# root:Engineered:Modeled:Simulated communities (DNA mixture) SRR606364 amplicon
# root:Engineered:Modeled:Simulated communities (DNA mixture) SRR606365 amplicon
# root:Engineered:Modeled:Simulated communities (DNA mixture) SRR606366 amplicon
# root:Engineered:Modeled:Simulated communities (DNA mixture) SRR606367 amplicon
# root:Engineered:Modeled:Simulated communities (DNA mixture) SRR606368 amplicon
# root:Engineered:Modeled:Simulated communities (DNA mixture) SRR606369 amplicon
# root:Engineered:Modeled:Simulated communities (DNA mixture) SRR606370 amplicon
# root:Engineered:Modeled:Simulated communities (DNA mixture) SRR606371 amplicon
# root:Engineered:Modeled:Simulated communities (DNA mixture) SRR606372 amplicon
# root:Engineered:Modeled:Simulated communities (DNA mixture) SRR606373 amplicon
# root:Engineered:Modeled:Simulated communities (DNA mixture) SRR606374 amplicon
# root:Engineered:Modeled:Simulated communities (DNA mixture) SRR606375 amplicon
# root:Engineered:Modeled:Simulated communities (DNA mixture) SRR606376 amplicon
# root:Engineered:Modeled:Simulated communities (DNA mixture) SRR606377 amplicon
# root:Engineered:Modeled:Simulated communities (DNA mixture) SRR606378 amplicon
# root:Engineered:Modeled:Simulated communities (DNA mixture) SRR606379 amplicon
# root:Engineered:Modeled:Simulated communities (DNA mixture) SRR606380 amplicon
# root:Engineered:Modeled:Simulated communities (DNA mixture) SRR606381 amplicon
# root:Engineered:Modeled:Simulated communities (DNA mixture) SRR606382 amplicon
# root:Engineered:Modeled:Simulated communities (DNA mixture) SRR606383 amplicon
# root:Engineered:Modeled:Simulated communities (DNA mixture) SRR606384 amplicon
# root:Engineered:Modeled:Simulated communities (DNA mixture) SRR606385 amplicon
# root:Engineered:Modeled:Simulated communities (DNA mixture) SRR596245 amplicon
# root:Engineered:Modeled:Simulated communities (DNA mixture) SRR606249 metagenomic
# root:Engineered:Modeled:Simulated communities (DNA mixture) SRR606245 metagenomic
# root:Engineered:Modeled:Simulated communities (DNA mixture) SRR606345 amplicon
# root:Engineered:Modeled:Simulated communities (DNA mixture) SRR606346 amplicon
# root:Engineered:Modeled:Simulated communities (DNA mixture) SRR606347 amplicon
# root:Engineered:Modeled:Simulated communities (DNA mixture) SRR606348 amplicon
# root:Engineered:Modeled:Simulated communities (DNA mixture) SRR606349 amplicon
# root:Engineered:Modeled:Simulated communities (DNA mixture) SRR606350 amplicon
# root:Engineered:Modeled:Simulated communities (DNA mixture) SRR606351 amplicon
# root:Engineered:Modeled:Simulated communities (DNA mixture) SRR606352 amplicon
# root:Engineered:Modeled:Simulated communities (DNA mixture) SRR606353 amplicon
# root:Engineered:Modeled:Simulated communities (DNA mixture) SRR606354 amplicon
# root:Engineered:Modeled:Simulated communities (DNA mixture) SRR606355 amplicon
# root:Engineered:Modeled:Simulated communities (DNA mixture) SRR606356 amplicon
# root:Engineered:Modeled:Simulated communities (DNA mixture) SRR606357 amplicon
# root:Engineered:Modeled:Simulated communities (DNA mixture) SRR606358 amplicon
# root:Engineered:Modeled:Simulated communities (DNA mixture) SRR606359 amplicon
# root:Engineered:Modeled:Simulated communities (DNA mixture) SRR606360 amplicon
# root:Engineered:Modeled:Simulated communities (DNA mixture) SRR606361 amplicon
# root:Engineered:Modeled:Simulated communities (DNA mixture) SRR606362 amplicon
# root:Engineered:Modeled:Simulated communities (DNA mixture) ERR776678 metagenomic
# root:Engineered:Modeled:Simulated communities (DNA mixture) ERR776677 metagenomic
# root:Engineered:Modeled:Simulated communities (DNA mixture) ERR340319 metagenomic
# root:Engineered:Modeled:Simulated communities (DNA mixture) SRR072233 metagenomic
# root:Engineered:Modeled:Simulated communities (DNA mixture) SRR072232 metagenomic
# root:Engineered:Bioremediation:Hydrocarbon ERR1818144 metagenomic
# root:Engineered:Bioremediation:Hydrocarbon ERR1818145 metagenomic
# root:Engineered:Bioremediation:Hydrocarbon ERR1121450 amplicon
# root:Engineered:Bioremediation:Hydrocarbon ERR1121451 amplicon
# root:Host-associated:Birds:Respiratory system ERR2192858 metagenomic
# root:Host-associated:Birds:Respiratory system ERR2192859 metagenomic
# root:Host-associated:Birds:Respiratory system ERR2192860 metagenomic
# root:Host-associated:Birds:Respiratory system ERR2192861 metagenomic
# root:Host-associated:Birds:Respiratory system ERR2192862 metagenomic
# root:Host-associated:Birds:Respiratory system ERR2192863 metagenomic
# root:Host-associated:Birds:Respiratory system ERR2192853 metagenomic
# root:Host-associated:Birds:Respiratory system ERR2192854 metagenomic
# root:Host-associated:Birds:Respiratory system ERR2192855 metagenomic
# root:Host-associated:Birds:Respiratory system ERR2192849 metagenomic
# root:Host-associated:Birds:Respiratory system ERR2192856 metagenomic
# root:Host-associated:Birds:Respiratory system ERR2192857 metagenomic
# root:Host-associated:Birds:Respiratory system ERR2192850 metagenomic
# root:Host-associated:Birds:Respiratory system ERR2111655 metagenomic
# root:Host-associated:Birds:Respiratory system ERR2111658 metagenomic
# root:Host-associated:Birds:Respiratory system ERR2111654 metagenomic
# root:Host-associated:Birds:Respiratory system ERR2111662 metagenomic
# root:Host-associated:Birds:Respiratory system ERR2111663 metagenomic
# root:Host-associated:Birds:Respiratory system ERR2192851 metagenomic
# root:Host-associated:Birds:Respiratory system ERR2111657 metagenomic
# root:Host-associated:Birds:Respiratory system ERR2192852 metagenomic
# root:Host-associated:Birds:Respiratory system ERR2111659 metagenomic
# root:Host-associated:Birds:Respiratory system ERR2111664 metagenomic
# root:Host-associated:Birds:Respiratory system ERR2111650 metagenomic
# root:Host-associated:Birds:Respiratory system ERR2111652 metagenomic
# root:Host-associated:Birds:Respiratory system ERR2111648 metagenomic
# root:Host-associated:Birds:Respiratory system ERR2111646 metagenomic
# root:Host-associated:Birds:Respiratory system ERR2111653 metagenomic
# root:Host-associated:Birds:Respiratory system ERR2111644 metagenomic
# root:Host-associated:Birds:Respiratory system ERR2111645 metagenomic
# root:Host-associated:Birds:Respiratory system ERR2027201 amplicon
# root:Host-associated:Birds:Respiratory system ERR2027610 amplicon
# root:Host-associated:Birds:Respiratory system ERR2027630 amplicon
# root:Host-associated:Birds:Respiratory system ERR2029268 amplicon
# root:Host-associated:Birds:Respiratory system ERR2029271 amplicon
# root:Host-associated:Birds:Respiratory system ERR2027145 amplicon
# root:Host-associated:Birds:Respiratory system ERR2027161 amplicon
# root:Host-associated:Birds:Respiratory system ERR2027183 amplicon
# root:Host-associated:Birds:Respiratory system ERR2027184 amplicon
# root:Host-associated:Birds:Respiratory system ERR2027611 amplicon
# root:Host-associated:Birds:Respiratory system ERR2027628 amplicon
# root:Host-associated:Birds:Respiratory system ERR2027629 amplicon
# root:Host-associated:Birds:Respiratory system ERR2027631 amplicon
# root:Host-associated:Birds:Respiratory system ERR2027632 amplicon
# root:Host-associated:Birds:Respiratory system ERR2027633 amplicon
# root:Host-associated:Birds:Respiratory system ERR2029267 amplicon
# root:Host-associated:Birds:Respiratory system ERR2029269 amplicon
# root:Host-associated:Birds:Respiratory system ERR2029270 amplicon
# root:Host-associated:Birds:Respiratory system ERR2029273 amplicon
# root:Host-associated:Birds:Respiratory system ERR2029274 amplicon
# root:Host-associated:Birds:Respiratory system ERR2030963 metagenomic
# root:Host-associated:Birds:Respiratory system ERR2030964 metagenomic
# root:Host-associated:Birds:Respiratory system ERR2030965 metagenomic
# root:Host-associated:Birds:Respiratory system ERR1886421 amplicon
# root:Host-associated:Birds:Respiratory system ERR1886422 amplicon
# root:Host-associated:Birds:Respiratory system ERR1886423 amplicon
# root:Host-associated:Birds:Respiratory system ERR1886424 amplicon
# root:Host-associated:Birds:Respiratory system ERR1880749 amplicon
# root:Host-associated:Birds:Respiratory system ERR1880750 amplicon
# root:Host-associated:Birds:Respiratory system ERR1880751 amplicon
# root:Host-associated:Birds:Respiratory system ERR1880752 amplicon
# root:Host-associated:Birds:Respiratory system ERR1880753 amplicon
# root:Host-associated:Birds:Respiratory system ERR1885279 amplicon
# root:Host-associated:Birds:Respiratory system ERR1856434 amplicon
# root:Host-associated:Birds:Respiratory system ERR1856435 amplicon
# root:Host-associated:Birds:Respiratory system ERR1856436 amplicon
# root:Host-associated:Birds:Respiratory system ERR1869440 amplicon
# root:Host-associated:Birds:Respiratory system ERR1869441 amplicon
# root:Host-associated:Birds:Respiratory system ERR1869436 amplicon
# root:Environmental:Aquatic:Estuary ERR4404431 metagenomic ILLUMINA HiSeq X Ten
# root:Environmental:Aquatic:Estuary ERR4404432 metagenomic ILLUMINA HiSeq X Ten
# root:Environmental:Aquatic:Estuary ERR4404430 metagenomic ILLUMINA HiSeq X Ten
# root:Environmental:Aquatic:Estuary ERR4404428 metagenomic ILLUMINA HiSeq X Ten
# root:Environmental:Aquatic:Estuary ERR4404429 metagenomic ILLUMINA HiSeq X Ten
# root:Environmental:Aquatic:Estuary ERR4404427 metagenomic ILLUMINA HiSeq X Ten
# root:Environmental:Aquatic:Estuary SRR6459199 metagenomic ILLUMINA Illumina MiSeq
# root:Environmental:Aquatic:Estuary SRR6459198 metagenomic ILLUMINA Illumina MiSeq
# root:Environmental:Aquatic:Estuary SRR6459197 metagenomic ILLUMINA Illumina MiSeq
# root:Environmental:Aquatic:Estuary SRR5468194 metagenomic ILLUMINA Illumina HiSeq 2500
# root:Environmental:Aquatic:Estuary SRR3359127 amplicon LS454 454 GS
# root:Environmental:Aquatic:Estuary SR