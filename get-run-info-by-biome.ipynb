# %%
# Connection to MGnify API
from jsonapi_client import Session as APISession
from jsonapi_client import Modifier
import requests

# Dataframes and display
import pandas as pd

pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# Data transformation
from functools import reduce

# %%
def get_all_biome_names():
    endpoint_name='biomes'
    r = requests.get(f"https://www.ebi.ac.uk/metagenomics/api/latest/{endpoint_name}")
    result = r.json()
    num_pages = result['meta']['pagination']['pages']

    xx = []
    for page in range(1, num_pages + 1):
        print(f'working on page: {page}')
        r = requests.get(f"https://www.ebi.ac.uk/metagenomics/api/latest/{endpoint_name}?page={page}")
        xx.append(r.json())

    print(f'got {len(xx)}')
    return xx

z = get_all_biome_names()
# Out:
# working on page: 1
# working on page: 2
# working on page: 3
# working on page: 4
# working on page: 5
# working on page: 6
# working on page: 7
# working on page: 8
# working on page: 9
# working on page: 10
# working on page: 11
# working on page: 12
# working on page: 13
# working on page: 14
# working on page: 15
# working on page: 16
# working on page: 17
# working on page: 18
# working on page: 19
# got 19

# %%
all_biomes=[]
for result in z:
    data = result['data']
    #print(data)
    for record in data:
        print(record['id'])
        print(record['attributes']['samples-count'])
        all_biomes.append((record['id'],record['attributes']['samples-count']))

orig_all_biomes = all_biomes
# Out:
# root:Engineered
# 284
# root:Engineered:Biogas plant
# 126
# root:Engineered:Biogas plant:Wet fermentation
# 111
# root:Engineered:Bioreactor
# 1003
# root:Engineered:Bioreactor:Continuous culture
# 648
# root:Engineered:Bioreactor:Continuous culture:Marine intertidal flat sediment inoculum
# 23
# root:Engineered:Bioreactor:Continuous culture:Marine intertidal flat sediment inoculum:Wadden Sea-Germany
# 5
# root:Engineered:Bioreactor:Continuous culture:Marine sediment inoculum
# 35
# root:Engineered:Bioreactor:Continuous culture:Marine sediment inoculum:Wadden Sea-Germany
# 8
# root:Engineered:Bioremediation
# 49
# root:Engineered:Bioremediation:Hydrocarbon
# 65
# root:Engineered:Bioremediation:Hydrocarbon:Benzene
# 0
# root:Engineered:Bioremediation:Hydrocarbon:Benzene:Bioreactor
# 2
# root:Engineered:Bioremediation:Metal
# 0
# root:Engineered:Bioremediation:Persistent organic pollutants (POP)
# 53
# root:Engineered:Bioremediation:Persistent organic pollutants (POP):Polycyclic aromatic hydrocarbons
# 0
# root:Engineered:Bioremediation:Terephthalate
# 0
# root:Engineered:Bioremediation:Terephthalate:Wastewater
# 92
# root:Engineered:Bioremediation:Terephthalate:Wastewater:Activated sludge
# 0
# root:Engineered:Bioremediation:Terephthalate:Wastewater:Bioreactor
# 4
# root:Engineered:Bioremediation:Tetrachloroethylene and derivatives
# 0
# root:Engineered:Bioremediation:Tetrachloroethylene and derivatives:Chloroethene
# 0
# root:Engineered:Bioremediation:Tetrachloroethylene and derivatives:Chloroethene:Bioreactor
# 0
# root:Engineered:Bioremediation:Tetrachloroethylene and derivatives:Tetrachloroethylene
# 0
# root:Engineered:Bioremediation:Tetrachloroethylene and derivatives:Tetrachloroethylene:Bioreactor
# 0
# root:Engineered:Biotransformation
# 13
# root:Engineered:Biotransformation:Microbial enhanced oil recovery
# 8
# root:Engineered:Biotransformation:Microbial solubilization of coal
# 0
# root:Engineered:Biotransformation:Mixed alcohol bioreactor
# 25
# root:Engineered:Built environment
# 758
# root:Engineered:Food production
# 394
# root:Engineered:Food production:Dairy products
# 1829
# root:Engineered:Food production:Fermented beverages
# 270
# root:Engineered:Food production:Fermented seafood
# 26
# root:Engineered:Food production:Fermented vegetables
# 395
# root:Engineered:Food production:Silage fermentation
# 12
# root:Engineered:Industrial production
# 13
# root:Engineered:Industrial production:Engineered product
# 0
# root:Engineered:Lab enrichment
# 259
# root:Engineered:Lab enrichment:Defined media
# 80
# root:Engineered:Lab enrichment:Defined media:Aerobic media
# 0
# root:Engineered:Lab enrichment:Defined media:Anaerobic media
# 63
# root:Engineered:Lab enrichment:Defined media:Marine media
# 53
# root:Engineered:Lab enrichment:Defined media:Marine media:Algoconsortia
# 0
# root:Engineered:Lab enrichment:Undefined media
# 0
# root:Engineered:Lab Synthesis
# 176
# root:Engineered:Lab Synthesis:Genetic cross
# 26
# root:Engineered:Modeled
# 99
# root:Engineered:Modeled:Simulated communities (DNA mixture)
# 59
# root:Engineered:Modeled:Simulated communities (microbial mixture)
# 656
# root:Engineered:Modeled:Simulated communities (sequence read mixture)
# 67
# root:Engineered:Modeled:Simulated communities (sequence read mixture):Sanger
# 0
# root:Engineered:Solid waste
# 141
# root:Engineered:Solid waste:Composting
# 159
# root:Engineered:Solid waste:Composting:Grass
# 3
# root:Engineered:Solid waste:Composting:Grass:Bioreactor
# 0
# root:Engineered:Solid waste:Composting:Bioreactor
# 2
# root:Engineered:Solid waste:Composting:Wood
# 111
# root:Engineered:Solid waste:Composting:Wood:Bioreactor
# 0
# root:Engineered:Solid waste:Landfill
# 1
# root:Engineered:Solid waste:Solid animal waste
# 12
# root:Engineered:Wastewater
# 615
# root:Engineered:Wastewater:Activated Sludge
# 1252
# root:Engineered:Wastewater:Industrial wastewater
# 306
# root:Engineered:Wastewater:Industrial wastewater:Agricultural wastewater
# 373
# root:Engineered:Wastewater:Industrial wastewater:Landfill leachate
# 0
# root:Engineered:Wastewater:Industrial wastewater:Mine water
# 79
# root:Engineered:Wastewater:Industrial wastewater:Petrochemical
# 16
# root:Engineered:Wastewater:Industrial wastewater:Pulp and paper wastewater
# 0
# root:Engineered:Wastewater:Nutrient removal
# 0
# root:Engineered:Wastewater:Nutrient removal:Biological phosphorus removal
# 0
# root:Engineered:Wastewater:Nutrient removal:Biological phosphorus removal:Activated sludge
# 17
# root:Engineered:Wastewater:Nutrient removal:Biological phosphorus removal:Bioreactor
# 414
# root:Engineered:Wastewater:Nutrient removal:Dissolved organics (aerobic)
# 48
# root:Engineered:Wastewater:Nutrient removal:Dissolved organics (aerobic):Activated sludge
# 0
# root:Engineered:Wastewater:Nutrient removal:Dissolved organics (anaerobic)
# 285
# root:Engineered:Wastewater:Nutrient removal:Dissolved organics (anaerobic):Activated sludge
# 0
# root:Engineered:Wastewater:Nutrient removal:Nitrogen removal
# 1
# root:Engineered:Wastewater:Nutrient removal:Nitrogen removal:Anammox
# 0
# root:Engineered:Wastewater:Water and sludge
# 958
# root:Environmental
# 63
# root:Environmental:Air
# 86
# root:Environmental:Air:Indoor Air
# 0
# root:Environmental:Air:Outdoor Air
# 17
# root:Environmental:Aquatic
# 446
# root:Environmental:Aquatic:Aquaculture
# 42
# root:Environmental:Aquatic:Estuary
# 70
# root:Environmental:Aquatic:Estuary:Sediment
# 611
# root:Environmental:Aquatic:Freshwater
# 413
# root:Environmental:Aquatic:Freshwater:Drinking water
# 148
# root:Environmental:Aquatic:Freshwater:Drinking water:Chlorinated
# 0
# root:Environmental:Aquatic:Freshwater:Drinking water:Delivery networks
# 94
# root:Environmental:Aquatic:Freshwater:Groundwater
# 740
# root:Environmental:Aquatic:Freshwater:Groundwater:Acid Mine Drainage
# 52
# root:Environmental:Aquatic:Freshwater:Groundwater:Biofilm
# 968
# root:Environmental:Aquatic:Freshwater:Groundwater:Cave water
# 7
# root:Environmental:Aquatic:Freshwater:Groundwater:Coalbed water
# 0
# root:Environmental:Aquatic:Freshwater:Groundwater:Contaminated
# 248
# root:Environmental:Aquatic:Freshwater:Groundwater:Mine
# 0
# root:Environmental:Aquatic:Freshwater:Groundwater:Mine drainage
# 12
# root:Environmental:Aquatic:Freshwater:Ice
# 91
# root:Environmental:Aquatic:Freshwater:Ice:Glacial lake
# 99
# root:Environmental:Aquatic:Freshwater:Ice:Glacier
# 166
# root:Environmental:Aquatic:Freshwater:Ice:Ice accretions
# 0
# root:Environmental:Aquatic:Freshwater:Lake
# 2986
# root:Environmental:Aquatic:Freshwater:Lentic
# 44
# root:Environmental:Aquatic:Freshwater:Lentic:Epilimnion
# 0
# root:Environmental:Aquatic:Freshwater:Lentic:Hypolimnion
# 0
# root:Environmental:Aquatic:Freshwater:Lentic:Limnetic zone
# 0
# root:Environmental:Aquatic:Freshwater:Lentic:Littoral zone
# 0
# root:Environmental:Aquatic:Freshwater:Lentic:Sediment
# 841
# root:Environmental:Aquatic:Freshwater:Lotic
# 154
# root:Environmental:Aquatic:Freshwater:Lotic:Acidic
# 1
# root:Environmental:Aquatic:Freshwater:Lotic:Low land river systems
# 78
# root:Environmental:Aquatic:Freshwater:Lotic:Microbial mats
# 5
# root:Environmental:Aquatic:Freshwater:Lotic:Mid stream
# 1
# root:Environmental:Aquatic:Freshwater:Lotic:Sediment
# 315
# root:Environmental:Aquatic:Freshwater:Microbialites
# 0
# root:Environmental:Aquatic:Freshwater:Pond
# 12
# root:Environmental:Aquatic:Freshwater:Pond:Sediment
# 94
# root:Environmental:Aquatic:Freshwater:Sediment
# 470
# root:Environmental:Aquatic:Freshwater:Storm water
# 63
# root:Environmental:Aquatic:Freshwater:Storm water:Drainage pipe biofilm
# 9
# root:Environmental:Aquatic:Freshwater:Subglacial lake
# 0
# root:Environmental:Aquatic:Freshwater:Wetlands
# 2
# root:Environmental:Aquatic:Freshwater:Wetlands:Bog
# 1545
# root:Environmental:Aquatic:Freshwater:Wetlands:Marsh
# 59
# root:Environmental:Aquatic:Freshwater:Wetlands:Sediment
# 229
# root:Environmental:Aquatic:Freshwater:Wetlands:Swamp
# 106
# root:Environmental:Aquatic:Lentic
# 43
# root:Environmental:Aquatic:Lentic:Brackish
# 64
# root:Environmental:Aquatic:Marine
# 20295
# root:Environmental:Aquatic:Marine:Brackish
# 32
# root:Environmental:Aquatic:Marine:Coastal
# 2740
# root:Environmental:Aquatic:Marine:Coastal:Sediment
# 1344
# root:Environmental:Aquatic:Marine:Cold seeps
# 572
# root:Environmental:Aquatic:Marine:Cold seeps:Sediment
# 63
# root:Environmental:Aquatic:Marine:Fossil
# 0
# root:Environmental:Aquatic:Marine:Fossil:Whale fall
# 0
# root:Environmental:Aquatic:Marine:Hydrothermal vents
# 191
# root:Environmental:Aquatic:Marine:Hydrothermal vents:Black smokers
# 3
# root:Environmental:Aquatic:Marine:Hydrothermal vents:Diffuse flow
# 19
# root:Environmental:Aquatic:Marine:Hydrothermal vents:Microbial mats
# 36
# root:Environmental:Aquatic:Marine:Hydrothermal vents:Sediment
# 85
# root:Environmental:Aquatic:Marine:Intertidal zone
# 123
# root:Environmental:Aquatic:Marine:Intertidal zone:Beach
# 0
# root:Environmental:Aquatic:Marine:Intertidal zone:Coral reef
# 1448
# root:Environmental:Aquatic:Marine:Intertidal zone:Estuary
# 1038
# root:Environmental:Aquatic:Marine:Intertidal zone:Mangrove swamp
# 166
# root:Environmental:Aquatic:Marine:Intertidal zone:Microbialites
# 5
# root:Environmental:Aquatic:Marine:Intertidal zone:Oil-contaminated
# 409
# root:Environmental:Aquatic:Marine:Intertidal zone:Salt marsh
# 559
# root:Environmental:Aquatic:Marine:Intertidal zone:Sediment
# 48
# root:Environmental:Aquatic:Marine:Marginal Sea
# 354
# root:Environmental:Aquatic:Marine:Neritic zone
# 74
# root:Environmental:Aquatic:Marine:Neritic zone:Oil-contaminated sediment
# 0
# root:Environmental:Aquatic:Marine:Neritic zone:Sediment
# 5
# root:Environmental:Aquatic:Marine:Oceanic
# 5927
# root:Environmental:Aquatic:Marine:Oceanic:Abyssal plane
# 792
# root:Environmental:Aquatic:Marine:Oceanic:Aphotic zone
# 76
# root:Environmental:Aquatic:Marine:Oceanic:Benthic
# 232
# root:Environmental:Aquatic:Marine:Oceanic:Oil-contaminated
# 234
# root:Environmental:Aquatic:Marine:Oceanic:Oil-contaminated sediments
# 49
# root:Environmental:Aquatic:Marine:Oceanic:Photic zone
# 334
# root:Environmental:Aquatic:Marine:Oceanic:Sediment
# 402
# root:Environmental:Aquatic:Marine:Oil field
# 0
# root:Environmental:Aquatic:Marine:Oil field:bore hole
# 1
# root:Environmental:Aquatic:Marine:Oil seeps
# 2
# root:Environmental:Aquatic:Marine:Pelagic
# 547
# root:Environmental:Aquatic:Marine:Oil-contaminated sediment
# 399
# root:Environmental:Aquatic:Marine:Sediment
# 4114
# root:Environmental:Aquatic:Marine:Volcanic
# 1
# root:Environmental:Aquatic:Marine:Wetlands
# 6
# root:Environmental:Aquatic:Marine:Wetlands:Sediment
# 125
# root:Environmental:Aquatic:Meromictic lake
# 0
# root:Environmental:Aquatic:Non-marine Saline and Alkaline
# 71
# root:Environmental:Aquatic:Non-marine Saline and Alkaline:Alkaline
# 1
# root:Environmental:Aquatic:Non-marine Saline and Alkaline:Alkaline:Carbonate
# 0
# root:Environmental:Aquatic:Non-marine Saline and Alkaline:Alkaline:Microbial mats
# 2
# root:Environmental:Aquatic:Non-marine Saline and Alkaline:Alkaline:Sediment
# 139
# root:Environmental:Aquatic:Non-marine Saline and Alkaline:Hypersaline
# 50
# root:Environmental:Aquatic:Non-marine Saline and Alkaline:Hypersaline:Microbial mats
# 5
# root:Environmental:Aquatic:Non-marine Saline and Alkaline:Hypersaline:Sediment
# 34
# root:Environmental:Aquatic:Non-marine Saline and Alkaline:Near-boiling (>90C)
# 0
# root:Environmental:Aquatic:Non-marine Saline and Alkaline:Near-boiling (>90C):Alkaline
# 0
# root:Environmental:Aquatic:Non-marine Saline and Alkaline:Saline
# 14
# root:Environmental:Aquatic:Non-marine Saline and Alkaline:Saline:Athalassic
# 0
# root:Environmental:Aquatic:Non-marine Saline and Alkaline:Saline:Epilimnion
# 0
# root:Environmental:Aquatic:Non-marine Saline and Alkaline:Saline:Hypolimnion
# 0
# root:Environmental:Aquatic:Non-marine Saline and Alkaline:Saline:Microbial mats
# 30
# root:Environmental:Aquatic:Non-marine Saline and Alkaline:Saline:Sediment
# 0
# root:Environmental:Aquatic:Non-marine Saline and Alkaline:Saline:Thalassic
# 0
# root:Environmental:Aquatic:Non-marine Saline and Alkaline:Salt crystallizer pond
# 106
# root:Environmental:Aquatic:Non-marine Saline and Alkaline:Salt crystallizer pond:Microbial mats
# 0
# root:Environmental:Aquatic:Sediment
# 870
# root:Environmental:Aquatic:Thermal springs
# 704
# root:Environmental:Aquatic:Thermal springs:Hot (42-90C)
# 127
# root:Environmental:Aquatic:Thermal springs:Hot (42-90C):Acidic
# 0
# root:Environmental:Aquatic:Thermal springs:Hot (42-90C):Alkaline
# 0
# root:Environmental:Aquatic:Thermal springs:Hot (42-90C):Neutral
# 0
# root:Environmental:Aquatic:Thermal springs:Hot (42-90C):Sediment
# 1
# root:Environmental:Aquatic:Thermal springs:Near-boiling (>90C)
# 3
# root:Environmental:Aquatic:Thermal springs:Near-boiling (>90C):Alkaline
# 2
# root:Environmental:Aquatic:Thermal springs:Sediment
# 17
# root:Environmental:Aquatic:Thermal springs:Tepid (25-34C)
# 0
# root:Environmental:Aquatic:Thermal springs:Tepid (25-34C):Sediment
# 0
# root:Environmental:Aquatic:Thermal springs:Warm (34-42C)
# 0
# root:Environmental:Aquatic:Thermal springs:Warm (34-42C):Neutral
# 0
# root:Environmental:Aquatic:Thermal springs:Warm (34-42C):Sediment
# 0
# root:Environmental:Terrestrial
# 0
# root:Environmental:Terrestrial:Agricultural field
# 52
# root:Environmental:Terrestrial:Asphalt lakes
# 0
# root:Environmental:Terrestrial:Asphalt lakes:Tar
# 0
# root:Environmental:Terrestrial:Deep subsurface
# 829
# root:Environmental:Terrestrial:Deep subsurface:Clay
# 0
# root:Environmental:Terrestrial:Geologic
# 85
# root:Environmental:Terrestrial:Geologic:Mine
# 0
# root:Environmental:Terrestrial:Oil reservoir
# 12
# root:Environmental:Terrestrial:Rock-dwelling (subaerial biofilm)
# 45
# root:Environmental:Terrestrial:Soil
# 13041
# root:Environmental:Terrestrial:Soil:Clay
# 19
# root:Environmental:Terrestrial:Soil:Clay:Agricultural land
# 0
# root:Environmental:Terrestrial:Soil:Clay:Contaminated
# 0
# root:Environmental:Terrestrial:Soil:Clay:Grasslands
# 0
# root:Environmental:Terrestrial:Soil:Clay:Oil-contaminated
# 134
# root:Environmental:Terrestrial:Soil:Crop
# 208
# root:Environmental:Terrestrial:Soil:Crop:Agricultural land
# 30
# root:Environmental:Terrestrial:Soil:Loam
# 51
# root:Environmental:Terrestrial:Soil:Loam:Agricultural
# 73
# root:Environmental:Terrestrial:Soil:Loam:Contaminated
# 121
# root:Environmental:Terrestrial:Soil:Loam:Forest soil
# 995
# root:Environmental:Terrestrial:Soil:Loam:Grasslands
# 0
# root:Environmental:Terrestrial:Soil:Sand
# 138
# root:Environmental:Terrestrial:Soil:Sand:Desert
# 4
# root:Environmental:Terrestrial:Soil:Sand:Forest soil
# 0
# root:Environmental:Terrestrial:Soil:Sand:Grasslands
# 0
# root:Environmental:Terrestrial:Soil:Sand:Oil-contaminated
# 32
# root:Environmental:Terrestrial:Soil:Silt
# 9
# root:Environmental:Terrestrial:Soil:Agricultural
# 4300
# root:Environmental:Terrestrial:Soil:Boreal forest
# 30
# root:Environmental:Terrestrial:Soil:Contaminated
# 887
# root:Environmental:Terrestrial:Soil:Desert
# 244
# root:Environmental:Terrestrial:Soil:Forest soil
# 3055
# root:Environmental:Terrestrial:Soil:Grasslands
# 1741
# root:Environmental:Terrestrial:Soil:Mine
# 50
# root:Environmental:Terrestrial:Soil:Mine drainage
# 1
# root:Environmental:Terrestrial:Soil:Oil-contaminated
# 196
# root:Environmental:Terrestrial:Soil:Permafrost
# 140
# root:Environmental:Terrestrial:Soil:Shrubland
# 0
# root:Environmental:Terrestrial:Soil:Tropical rainforest
# 320
# root:Environmental:Terrestrial:Soil:Uranium contaminated
# 11
# root:Environmental:Terrestrial:Soil:Viriome
# 0
# root:Environmental:Terrestrial:Soil:Wetlands
# 59
# root:Environmental:Terrestrial:Soil:Wetlands:Permafrost
# 4
# root:Environmental:Terrestrial:Volcanic
# 16
# root:Environmental:Terrestrial:Volcanic:Fumaroles
# 0
# root:Host-associated
# 1772
# root:Host-associated:Algae
# 422
# root:Host-associated:Algae:Brown Algae
# 179
# root:Host-associated:Algae:Green algae
# 0
# root:Host-associated:Algae:Green algae:Ectosymbionts
# 0
# root:Host-associated:Algae:Red algae
# 9
# root:Host-associated:Algae:Red algae:Ectosymbionts
# 0
# root:Host-associated:Amphibia
# 122
# root:Host-associated:Amphibia:Digestive system
# 0
# root:Host-associated:Amphibia:Excretory system
# 0
# root:Host-associated:Animal
# 961
# root:Host-associated:Animal:Circulatory system
# 0
# root:Host-associated:Animal:Digestive system
# 233
# root:Host-associated:Animal:Digestive system:Fecal
# 1999
# root:Host-associated:Animal:Fossil
# 0
# root:Host-associated:Animal:Fossil:Bone
# 0
# root:Host-associated:Animal:Fossil:Feces
# 0
# root:Host-associated:Animal:Reproductive system
# 0
# root:Host-associated:Animal:Respiratory system
# 0
# root:Host-associated:Animal:Skin
# 0
# root:Host-associated:Annelida
# 4
# root:Host-associated:Annelida:Digestive system
# 1
# root:Host-associated:Annelida:Digestive system:Digestive tube
# 0
# root:Host-associated:Annelida:Digestive system:Digestive tube:Extracellular symbionts
# 0
# root:Host-associated:Annelida:Integument
# 0
# root:Host-associated:Annelida:Integument:Cuticle
# 0
# root:Host-associated:Annelida:Integument:Cuticle:Epibionts
# 0
# root:Host-associated:Annelida:Integument:Subcuticular space
# 0
# root:Host-associated:Annelida:Integument:Subcuticular space:Extracellular symbionts
# 0
# root:Host-associated:Annelida:Intracellular endosymbionts
# 0
# root:Host-associated:Annelida:Intracellular endosymbionts:Trophosome
# 0
# root:Host-associated:Annelida:Reproductive system
# 0
# root:Host-associated:Annelida:Reproductive system:Egg capsule
# 0
# root:Host-associated:Annelida:Reproductive system:Egg capsule:Extracellular
# 0
# root:Host-associated:Arthropoda
# 359
# root:Host-associated:Arthropoda:Digestive system
# 0
# root:Host-associated:Arthropoda:Digestive system:Foregut
# 0
# root:Host-associated:Arthropoda:Digestive system:Gut
# 69
# root:Host-associated:Arthropoda:Digestive system:Gut:P3 segment
# 0
# root:Host-associated:Arthropoda:Digestive system:Gut:Proctodeal segment
# 0
# root:Host-associated:Arthropoda:Digestive system:Hindgut
# 13
# root:Host-associated:Arthropoda:Digestive system:Hindgut:P1 segment
# 0
# root:Host-associated:Arthropoda:Digestive system:Hindgut:P3 segment
# 0
# root:Host-associated:Arthropoda:Digestive system:Midgut
# 0
# root:Host-associated:Arthropoda:Digestive system:Oral
# 1
# root:Host-associated:Arthropoda:Digestive system:Oral:Saliva
# 7
# root:Host-associated:Arthropoda:Integument
# 0
# root:Host-associated:Arthropoda:Integument:Cuticle
# 0
# root:Host-associated:Arthropoda:Integument:Cuticle:Thoracic segments
# 0
# root:Host-associated:Arthropoda:Intracellular endosymbionts
# 0
# root:Host-associated:Arthropoda:Intracellular endosymbionts:Primary
# 0
# root:Host-associated:Arthropoda:Intracellular endosymbionts:Primary:Bacteriomes
# 0
# root:Host-associated:Arthropoda:Intracellular endosymbionts:Secondary
# 0
# root:Host-associated:Arthropoda:Oral cavity
# 0
# root:Host-associated:Arthropoda:Respiratory system
# 0
# root:Host-associated:Arthropoda:Respiratory system:Gills
# 20
# root:Host-associated:Arthropoda:Symbiotic fungal gardens and galleries
# 0
# root:Host-associated:Arthropoda:Symbiotic fungal gardens and galleries:Fungus gallery
# 0
# root:Host-associated:Arthropoda:Symbiotic fungal gardens and galleries:Fungus garden
# 0
# root:Host-associated:Arthropoda:Symbiotic fungal gardens and galleries:Fungus garden:Garden dump
# 0
# root:Host-associated:Arthropoda:Venom gland
# 0
# root:Host-associated:Arthropoda:Venom gland:Venom
# 0
# root:Host-associated:Birds
# 1390
# root:Host-associated:Birds:Circulatory system
# 0
# root:Host-associated:Birds:Circulatory system:Blood
# 0
# root:Host-associated:Birds:Digestive system
# 2034
# root:Host-associated:Birds:Digestive system:Ceca
# 1776
# root:Host-associated:Birds:Digestive system:Ceca:Lumen
# 0
# root:Host-associated:Birds:Digestive system:Crop
# 0
# root:Host-associated:Birds:Digestive system:Crop:Lumen
# 0
# root:Host-associated:Birds:Digestive system:Digestive tube
# 263
# root:Host-associated:Birds:Digestive system:Digestive tube:Cecum
# 2414
# root:Host-associated:Birds:Digestive system:Fecal
# 630
# root:Host-associated:Birds:Digestive system:Small intestine
# 0
# root:Host-associated:Birds:Digestive system:Small intestine:Duodenal
# 0
# root:Host-associated:Birds:Reproductive system
# 0
# root:Host-associated:Birds:Respiratory system
# 67
# root:Host-associated:Birds:Respiratory system:Lungs
# 0
# root:Host-associated:Cnidaria
# 196
# root:Host-associated:Echinodermata
# 0
# root:Host-associated:Endosymbionts
# 0
# root:Host-associated:Endosymbionts:Fungi
# 0
# root:Host-associated:Endosymbionts:Fungi:Endosymbionts
# 0
# root:Host-associated:Fish
# 1056
# root:Host-associated:Fish:Circulatory system
# 0
# root:Host-associated:Fish:Circulatory system:Blood
# 0
# root:Host-associated:Fish:Digestive system
# 704
# root:Host-associated:Fish:Digestive system:Foregut
# 102
# root:Host-associated:Fish:Digestive system:Foregut:Uncharacterized
# 0
# root:Host-associated:Fish:Digestive system:Intestine
# 762
# root:Host-associated:Fish:Excretory system
# 0
# root:Host-associated:Fish:Excretory system:Kidneys
# 0
# root:Host-associated:Fish:Reproductive system
# 0
# root:Host-associated:Fish:Skin
# 51
# root:Host-associated:Fish:Skin:Slime
# 0
# root:Host-associated:Fungi
# 628
# root:Host-associated:Human
# 38152
# root:Host-associated:Human:Circulatory system
# 46
# root:Host-associated:Human:Circulatory system:Blood
# 231
# root:Host-associated:Human:Digestive system
# 20067
# root:Host-associated:Human:Digestive system:Hindgut
# 20
# root:Host-associated:Human:Digestive system:Hindgut:Rectum
# 339
# root:Host-associated:Human:Digestive system:Intestine
# 494
# root:Host-associated:Human:Digestive system:Large intestine
# 3541
# root:Host-associated:Human:Digestive system:Large intestine:Fecal
# 57837
# root:Host-associated:Human:Digestive system:Large intestine:Sigmoid colon
# 497
# root:Host-associated:Human:Digestive system:Oral
# 16502
# root:Host-associated:Human:Digestive system:Oral:Attached Keratinized gingiva
# 0
# root:Host-associated:Human:Digestive system:Oral:buccal mucosa
# 288
# root:Host-associated:Human:Digestive system:Oral:hard palate
# 0
# root:Host-associated:Human:Digestive system:Oral:Palatine tonsils
# 0
# root:Host-associated:Human:Digestive system:Oral:Periodontal pockets
# 10
# root:Host-associated:Human:Digestive system:Oral:Saliva
# 6511
# root:Host-associated:Human:Digestive system:Oral:Subgingival plaque
# 933
# root:Host-associated:Human:Digestive system:Oral:Supragingival plaque
# 513
# root:Host-associated:Human:Digestive system:Oral:Throat
# 1487
# root:Host-associated:Human:Digestive system:Oral:tongue dorsum
# 1985
# root:Host-associated:Human:Excretory system
# 0
# root:Host-associated:Human:Excretory system:Urethra
# 0
# root:Host-associated:Human:Excretory system:Urethra:Urine
# 366
# root:Host-associated:Human:Fossil
# 0
# root:Host-associated:Human:Fossil:Bone
# 0
# root:Host-associated:Human:Lympathic system
# 0
# root:Host-associated:Human:Lympathic system:Lymph nodes
# 0
# root:Host-associated:Human:Milk
# 10
# root:Host-associated:Human:Nervous system
# 0
# root:Host-associated:Human:Nervous system:Cerebrospinal fluid
# 0
# root:Host-associated:Human:Reproductive system
# 0
# root:Host-associated:Human:Reproductive system:Female
# 1648
# root:Host-associated:Human:Reproductive system:Vagina
# 10196
# root:Host-associated:Human:Reproductive system:Vagina:Introitus
# 0
# root:Host-associated:Human:Reproductive system:Vagina:Midpoint vagina
# 0
# root:Host-associated:Human:Reproductive system:Vagina:posterior fornix
# 493
# root:Host-associated:Human:Respiratory system
# 105
# root:Host-associated:Human:Respiratory system:Nasopharyngeal
# 9354
# root:Host-associated:Human:Respiratory system:Nasopharyngeal:anterior nares
# 0
# root:Host-associated:Human:Respiratory system:Nasopharyngeal:Nasal cavity
# 557
# root:Host-associated:Human:Respiratory system:Nasopharyngeal:Pharynx
# 2550
# root:Host-associated:Human:Respiratory system:Pulmonary system
# 976
# root:Host-associated:Human:Respiratory system:Pulmonary system:Lung
# 17524
# root:Host-associated:Human:Respiratory system:Pulmonary system:Sputum
# 8699
# root:Host-associated:Human:Respiratory system:Pulmonary system:Trachea
# 416
# root:Host-associated:Human:Respiratory system:Pulmonary system:Viriome
# 0
# root:Host-associated:Human:Skin
# 11407
# root:Host-associated:Human:Skin:Axilla
# 0
# root:Host-associated:Human:Skin:Medial distal leg
# 0
# root:Host-associated:Human:Skin:Medial distal leg:Venous leg ulcers
# 0
# root:Host-associated:Human:Skin:Naris
# 120
# root:Host-associated:Human:Skin:retroauricular crease
# 0
# root:Host-associated:Human:Skin:Umbilicus
# 0
# root:Host-associated:Human:Skin:Volar forearm
# 0
# root:Host-associated:Insecta
# 2857
# root:Host-associated:Insecta:Digestive system
# 1220
# root:Host-associated:Invertebrates
# 2
# root:Host-associated:Invertebrates:Bryozoans
# 0
# root:Host-associated:Invertebrates:Bryozoans:Gymnolaemates
# 0
# root:Host-associated:Invertebrates:Cnidaria
# 7
# root:Host-associated:Invertebrates:Cnidaria:Coral
# 165
# root:Host-associated:Invertebrates:Echinodermata
# 18
# root:Host-associated:Invertebrates:Echinodermata:Sea Urchin
# 0
# root:Host-associated:Mammals
# 3862
# root:Host-associated:Mammals:Circulatory system
# 0
# root:Host-associated:Mammals:Circulatory system:Blood
# 19
# root:Host-associated:Mammals:Digestive system
# 12258
# root:Host-associated:Mammals:Digestive system:Fecal
# 10404
# root:Host-associated:Mammals:Digestive system:Fecal:Uncharacterized
# 0
# root:Host-associated:Mammals:Digestive system:Foregut
# 12
# root:Host-associated:Mammals:Digestive system:Foregut:Rumen
# 181
# root:Host-associated:Mammals:Digestive system:Large intestine
# 862
# root:Host-associated:Mammals:Digestive system:Large intestine:Cecum
# 1163
# root:Host-associated:Mammals:Digestive system:Large intestine:Fecal
# 6410
# root:Host-associated:Mammals:Digestive system:Midgut
# 82
# root:Host-associated:Mammals:Digestive system:Oral cavity
# 0
# root:Host-associated:Mammals:Digestive system:Oral cavity:Buccal mucosa
# 4
# root:Host-associated:Mammals:Digestive system:Stomach
# 3
# root:Host-associated:Mammals:Digestive system:Stomach:Endoperitrophic space
# 0
# root:Host-associated:Mammals:Digestive system:Stomach:Rumen
# 4164
# root:Host-associated:Mammals:Excretory system
# 1
# root:Host-associated:Mammals:Excretory system:Urine
# 0
# root:Host-associated:Mammals:Gastrointestinal tract
# 1591
# root:Host-associated:Mammals:Gastrointestinal tract:Intestine
# 1071
# root:Host-associated:Mammals:Gastrointestinal tract:Intestine:Fecal
# 3349
# root:Host-associated:Mammals:Lymphatic
# 0
# root:Host-associated:Mammals:Lymphatic:Lymph nodes
# 0
# root:Host-associated:Mammals:Milk
# 72
# root:Host-associated:Mammals:Nervous system
# 0
# root:Host-associated:Mammals:Nervous system:Brain
# 14
# root:Host-associated:Mammals:Reproductive system
# 0
# root:Host-associated:Mammals:Respiratory system
# 1088
# root:Host-associated:Mammals:Respiratory system:Nasopharyngeal
# 222
# root:Host-associated:Mammals:Respiratory system:Nasopharyngeal:Nasal cavity
# 0
# root:Host-associated:Mammals:Respiratory system:Pulmonary system
# 343
# root:Host-associated:Mammals:Respiratory system:Pulmonary system:Viriome
# 0
# root:Host-associated:Mammals:Skin
# 1056
# root:Host-associated:Microbial
# 1
# root:Host-associated:Microbial:Bacteria
# 6
# root:Host-associated:Microbial:Dinoflagellates
# 0
# root:Host-associated:Microbial:Dinoflagellates:Endosymbionts
# 0
# root:Host-associated:Mollusca
# 107
# root:Host-associated:Mollusca:Digestive system
# 819
# root:Host-associated:Mollusca:Digestive system:Ceca
# 0
# root:Host-associated:Mollusca:Digestive system:Ceca:Uncharacterized
# 0
# root:Host-associated:Mollusca:Digestive system:Glands
# 1
# root:Host-associated:Mollusca:Respiratory system
# 6
# root:Host-associated:Mollusca:Respiratory system:Gills
# 0
# root:Host-associated:Mollusca:Respiratory system:Gills:Extracellular
# 0
# root:Host-associated:Mollusca:Respiratory system:Gills:Intracellular
# 0
# root:Host-associated:Mollusca:Shell
# 0
# root:Host-associated:Plants
# 9150
# root:Host-associated:Plants:Phylloplane
# 1894
# root:Host-associated:Plants:Phylloplane:Endophytes
# 196
# root:Host-associated:Plants:Phylloplane:Epiphytes
# 2
# root:Host-associated:Plants:Rhizome
# 370
# root:Host-associated:Plants:Rhizome:Epiphytes
# 0
# root:Host-associated:Plants:Rhizoplane
# 0
# root:Host-associated:Plants:Rhizoplane:Endophytes
# 1265
# root:Host-associated:Plants:Rhizoplane:Epiphytes
# 0
# root:Host-associated:Plants:Rhizoplane:Soil
# 75
# root:Host-associated:Plants:Rhizosphere
# 5268

# %%
all_biomes = orig_all_biomes
all_biomes.sort(key=lambda x: x[1])
print("all:", len(all_biomes))
all_biomes = [ (x, y) for (x, y) in all_biomes if y > 0 ]
print("0-filtered:", len(all_biomes))
all_biomes = [ (x, y) for (x, y) in all_biomes if y >= 10 ]
print("10-filtered:", len(all_biomes))
all_biomes = [ (x, y) for (x, y) in all_biomes if y >= 50 ]
print("50-filtered:", len(all_biomes))

all_biomes[:50]
# Out:
# all: 475
# 0-filtered: 289
# 10-filtered: 242
# 50-filtered: 196
# [('root:Environmental:Aquatic:Non-marine Saline and Alkaline:Hypersaline', 50),
#  ('root:Environmental:Terrestrial:Soil:Mine', 50),
#  ('root:Environmental:Terrestrial:Soil:Loam', 51),
#  ('root:Host-associated:Fish:Skin', 51),
#  ('root:Environmental:Aquatic:Freshwater:Groundwater:Acid Mine Drainage', 52),
#  ('root:Environmental:Terrestrial:Agricultural field', 52),
#  ('root:Engineered:Bioremediation:Persistent organic pollutants (POP)', 53),
#  ('root:Engineered:Lab enrichment:Defined media:Marine media', 53),
#  ('root:Engineered:Modeled:Simulated communities (DNA mixture)', 59),
#  ('root:Environmental:Aquatic:Freshwater:Wetlands:Marsh', 59),
#  ('root:Environmental:Terrestrial:Soil:Wetlands', 59),
#  ('root:Engineered:Lab enrichment:Defined media:Anaerobic media', 63),
#  ('root:Environmental', 63),
#  ('root:Environmental:Aquatic:Freshwater:Storm water', 63),
#  ('root:Environmental:Aquatic:Marine:Cold seeps:Sediment', 63),
#  ('root:Environmental:Aquatic:Lentic:Brackish', 64),
#  ('root:Engineered:Bioremediation:Hydrocarbon', 65),
#  ('root:Engineered:Modeled:Simulated communities (sequence read mixture)', 67),
#  ('root:Host-associated:Birds:Respiratory system', 67),
#  ('root:Host-associated:Arthropoda:Digestive system:Gut', 69),
#  ('root:Environmental:Aquatic:Estuary', 70),
#  ('root:Environmental:Aquatic:Non-marine Saline and Alkaline', 71),
#  ('root:Host-associated:Mammals:Milk', 72),
#  ('root:Environmental:Terrestrial:Soil:Loam:Agricultural', 73),
#  ('root:Environmental:Aquatic:Marine:Neritic zone', 74),
#  ('root:Host-associated:Plants:Rhizoplane:Soil', 75),
#  ('root:Environmental:Aquatic:Marine:Oceanic:Aphotic zone', 76),
#  ('root:Environmental:Aquatic:Freshwater:Lotic:Low land river systems', 78),
#  ('root:Engineered:Wastewater:Industrial wastewater:Mine water', 79),
#  ('root:Engineered:Lab enrichment:Defined media', 80),
#  ('root:Host-associated:Mammals:Digestive system:Midgut', 82),
#  ('root:Environmental:Aquatic:Marine:Hydrothermal vents:Sediment', 85),
#  ('root:Environmental:Terrestrial:Geologic', 85),
#  ('root:Environmental:Air', 86),
#  ('root:Environmental:Aquatic:Freshwater:Ice', 91),
#  ('root:Engineered:Bioremediation:Terephthalate:Wastewater', 92),
#  ('root:Environmental:Aquatic:Freshwater:Drinking water:Delivery networks',
#   94),
#  ('root:Environmental:Aquatic:Freshwater:Pond:Sediment', 94),
#  ('root:Engineered:Modeled', 99),
#  ('root:Environmental:Aquatic:Freshwater:Ice:Glacial lake', 99),
#  ('root:Host-associated:Fish:Digestive system:Foregut', 102),
#  ('root:Host-associated:Human:Respiratory system', 105),
#  ('root:Environmental:Aquatic:Freshwater:Wetlands:Swamp', 106),
#  ('root:Environmental:Aquatic:Non-marine Saline and Alkaline:Salt crystallizer pond',
#   106),
#  ('root:Host-associated:Mollusca', 107),
#  ('root:Engineered:Biogas plant:Wet fermentation', 111),
#  ('root:Engineered:Solid waste:Composting:Wood', 111),
#  ('root:Host-associated:Human:Skin:Naris', 120),
#  ('root:Environmental:Terrestrial:Soil:Loam:Contaminated', 121),
#  ('root:Host-associated:Amphibia', 122)]

# %%
def get_samples_for_biome(biome):
    endpoint_name='biomes'
    r = requests.get(f"https://www.ebi.ac.uk/metagenomics/api/latest/{endpoint_name}/{biome}/samples")
    result = r.json()
    num_pages = result['meta']['pagination']['pages']

    xx = []
    for page in range(1, num_pages + 1):
        print(f'working on page: {page} of {num_pages}')
        r = requests.get(f"https://www.ebi.ac.uk/metagenomics/api/latest/{endpoint_name}/{biome}/samples?page={page}")
        xx.append(r.json())

    print(f'got {len(xx)} pages')
    return xx

#biome_name = all_biomes[0][0]
#samples_from_biomes = get_samples_for_biome(biome_name)
# Out:
# working on page: 1 of 4
# working on page: 2 of 4
# working on page: 3 of 4
# working on page: 4 of 4
# got 4

# %%
def get_runs_from_samples(samples_data):
    xx = []
    for item in samples_data:
        for item2 in item['data']:
            xx.append(item2['relationships']['runs']['links']['related'])
    return xx

runs_from_samples = get_runs_from_samples(samples_from_biomes)

# %%
runs_from_samples
# Out:
# ['https://www.ebi.ac.uk/metagenomics/api/v1/samples/SRS9995124/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS5886824/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS5886826/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS5886825/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS5886828/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS5886827/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS4409919/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS4413232/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS4413234/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS4413248/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS4413260/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS4413262/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS4413265/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS4413276/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS4413278/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS4413282/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS4413284/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS4413281/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/SRS1379411/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS3036499/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS3037841/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS3037840/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS3040056/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS3040055/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS3104179/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/SRS475645/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/SRS475671/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/SRS475948/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/SRS476343/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/SRS476788/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/SRS463865/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/SRS470596/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/SRS470597/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/SRS470598/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/SRS470599/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/SRS470618/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/SRS470620/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/SRS470621/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/SRS470623/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/SRS475486/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS696577/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS696578/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS696579/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS696580/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/SRS1414572/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/SRS948184/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/SRS948190/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/SRS3007729/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/SRS3007730/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/SRS3007731/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/SRS3007732/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/SRS3007910/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/SRS3007911/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS756985/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS756986/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS756987/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS756988/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS756989/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS756990/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS756991/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS756992/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS758253/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS719958/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS719959/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS719960/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS719961/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS719962/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS719963/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS719964/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS719965/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS719966/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS719967/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS719968/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS719969/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS719970/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS719971/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS529626/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS529627/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS1459885/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS1459886/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS1459887/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS1459888/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS1459889/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS1459890/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS1455389/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS1455390/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/ERS1455391/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/SRS464643/runs',
#  'https://www.ebi.ac.uk/metagenomics/api/v1/samples/SRS478661/runs']

# %%
def get_run_info_for_runs(run_urls):
    zz = []
    for n, run_url in enumerate(run_urls):
        print(f"{n + 1} of {len(run_urls)}")
        r = requests.get(run_url)
        result = r.json()
        num_pages = result['meta']['pagination']['pages']
        if num_pages == 1:
            zz.append(result)
        else:
            assert 0

            for page in range(1, num_pages + 1):
                print(f'working on page: {page} of {num_pages} for run URL {run_url}')        
                r = requests.get(run_url + f"?page={page}")
                zz.append(r.json)

    return zz

run_info = get_run_info_for_runs(runs_from_samples)
# Out:
# 0 of 89
# 1 of 89
# 2 of 89
# 3 of 89
# 4 of 89
# 5 of 89
# 6 of 89
# 7 of 89
# 8 of 89
# 9 of 89
# 10 of 89
# 11 of 89
# 12 of 89
# 13 of 89
# 14 of 89
# 15 of 89
# 16 of 89
# 17 of 89
# 18 of 89
# 19 of 89
# 20 of 89
# 21 of 89
# 22 of 89
# 23 of 89
# 24 of 89
# 25 of 89
# 26 of 89
# 27 of 89
# 28 of 89
# 29 of 89
# 30 of 89
# 31 of 89
# 32 of 89
# 33 of 89
# 34 of 89
# 35 of 89
# 36 of 89
# 37 of 89
# 38 of 89
# 39 of 89
# 40 of 89
# 41 of 89
# 42 of 89
# 43 of 89
# 44 of 89
# 45 of 89
# 46 of 89
# 47 of 89
# 48 of 89
# 49 of 89
# 50 of 89
# 51 of 89
# 52 of 89
# 53 of 89
# 54 of 89
# 55 of 89
# 56 of 89
# 57 of 89
# 58 of 89
# 59 of 89
# 60 of 89
# 61 of 89
# 62 of 89
# 63 of 89
# 64 of 89
# 65 of 89
# 66 of 89
# 67 of 89
# 68 of 89
# 69 of 89
# 70 of 89
# 71 of 89
# 72 of 89
# 73 of 89
# 74 of 89
# 75 of 89
# 76 of 89
# 77 of 89
# 78 of 89
# 79 of 89
# 80 of 89
# 81 of 89
# 82 of 89
# 83 of 89
# 84 of 89
# 85 of 89
# 86 of 89
# 87 of 89
# 88 of 89

# %%
len(run_info)
# Out:
# 89

# %%
run_info[0]['data'][0]['attributes']
# Out:
# {'experiment-type': 'metagenomic',
#  'is-private': False,
#  'accession': 'SRR15691272',
#  'secondary-accession': 'SRR15691272',
#  'ena-study-accession': None,
#  'instrument-platform': 'ILLUMINA',
#  'instrument-model': 'Illumina NovaSeq 6000'}

# %%
for ri in run_info:
    for item in ri['data']:
        attr = item.get('attributes')
        print(attr['accession'], attr['experiment-type'], attr['instrument-platform'], attr['instrument-model'])
# Out:
# SRR15691272 metagenomic ILLUMINA Illumina NovaSeq 6000
# ERR5416478 unknown ILLUMINA Illumina HiSeq 3000
# ERR5416927 unknown ILLUMINA Illumina HiSeq 3000
# ERR5416479 unknown ILLUMINA Illumina HiSeq 3000
# ERR5416480 unknown ILLUMINA Illumina HiSeq 3000
# ERR5416520 unknown ILLUMINA Illumina HiSeq 3000
# ERR4007995 amplicon ILLUMINA Illumina MiSeq
# ERR4008002 amplicon ILLUMINA Illumina MiSeq
# ERR4008004 amplicon ILLUMINA Illumina MiSeq
# ERR4008006 amplicon ILLUMINA Illumina MiSeq
# ERR4008008 amplicon ILLUMINA Illumina MiSeq
# ERR4008009 amplicon ILLUMINA Illumina MiSeq
# ERR4008051 amplicon ILLUMINA Illumina MiSeq
# ERR4008052 amplicon ILLUMINA Illumina MiSeq
# ERR4008054 amplicon ILLUMINA Illumina MiSeq
# ERR4008058 amplicon ILLUMINA Illumina MiSeq
# ERR4008061 amplicon ILLUMINA Illumina MiSeq
# ERR4008062 amplicon ILLUMINA Illumina MiSeq
# SRR3341855 metagenomic ILLUMINA Illumina Genome Analyzer IIx
# SRR3341747 metagenomic ILLUMINA Illumina Genome Analyzer IIx
# SRR3341746 metagenomic ILLUMINA Illumina Genome Analyzer IIx
# ERR3079486 metagenomic ILLUMINA Illumina MiSeq
# ERR3085930 metagenomic ILLUMINA Illumina MiSeq
# ERR3085921 metagenomic ILLUMINA Illumina MiSeq
# ERR3083899 metagenomic ILLUMINA Illumina MiSeq
# ERR3082345 metagenomic ILLUMINA Illumina MiSeq
# ERR3132464 metagenomic ILLUMINA Illumina MiSeq
# ERR3132463 metagenomic ILLUMINA Illumina MiSeq
# ERR3132462 metagenomic ILLUMINA Illumina MiSeq
# SRR1171844 amplicon LS454 454 GS FLX Titanium
# SRR1171846 amplicon LS454 454 GS FLX Titanium
# SRR1171848 amplicon LS454 454 GS FLX Titanium
# SRR1171849 amplicon LS454 454 GS FLX Titanium
# SRR1171851 amplicon LS454 454 GS FLX Titanium
# SRR952665 amplicon LS454 454 GS FLX Titanium
# SRR952911 amplicon LS454 454 GS FLX+
# SRR952912 amplicon LS454 454 GS FLX Titanium
# SRR952913 amplicon LS454 454 GS FLX Titanium
# SRR952914 amplicon LS454 454 GS FLX Titanium
# SRR952915 amplicon LS454 454 GS FLX Titanium
# SRR952916 amplicon LS454 454 GS FLX Titanium
# SRR952917 amplicon LS454 454 GS FLX Titanium
# SRR952918 amplicon LS454 454 GS FLX Titanium
# SRR961678 amplicon LS454 454 GS FLX Titanium
# ERR841769 amplicon LS454 454 GS FLX+
# ERR841770 amplicon LS454 454 GS FLX+
# ERR841771 amplicon LS454 454 GS FLX+
# ERR841772 amplicon LS454 454 GS FLX+
# SRR3480638 amplicon LS454 454 GS FLX Titanium
# SRR3453161 amplicon LS454 454 GS FLX Titanium
# SRR2043654 amplicon ILLUMINA Illumina MiSeq
# SRR2043661 amplicon ILLUMINA Illumina MiSeq
# SRR6792326 amplicon ION_TORRENT Ion Torrent PGM
# SRR6792325 amplicon ION_TORRENT Ion Torrent PGM
# SRR6792327 amplicon ION_TORRENT Ion Torrent PGM
# SRR6792323 amplicon ION_TORRENT Ion Torrent PGM
# SRR6792328 amplicon ION_TORRENT Ion Torrent PGM
# SRR6792324 amplicon ION_TORRENT Ion Torrent PGM
# ERR921017 amplicon
# ERR921018 amplicon
# ERR921019 amplicon
# ERR921020 amplicon
# ERR921021 amplicon
# ERR921022 amplicon
# ERR921023 amplicon
# ERR921024 amplicon
# ERR921728 amplicon
# ERR876028 amplicon
# ERR876029 amplicon
# ERR876030 amplicon
# ERR876031 amplicon
# ERR876032 amplicon
# ERR876033 amplicon
# ERR876034 amplicon
# ERR876035 amplicon
# ERR876036 amplicon
# ERR876037 amplicon
# ERR876038 amplicon
# ERR876039 amplicon
# ERR876040 amplicon
# ERR876041 amplicon
# ERR580982 amplicon
# ERR580981 amplicon
# ERR580980 amplicon
# ERR580979 amplicon
# ERR580978 amplicon
# ERR580977 amplicon
# ERR580988 amplicon
# ERR580987 amplicon
# ERR580986 amplicon
# ERR580985 amplicon
# ERR580984 amplicon
# ERR580983 amplicon
# ERR1742997 metagenomic
# ERR1742998 metagenomic
# ERR1742999 metagenomic
# ERR1743000 metagenomic
# ERR1743001 metagenomic
# ERR1743002 metagenomic
# ERR1739731 metagenomic
# ERR1739732 metagenomic
# ERR1739733 metagenomic
# SRR944625 metagenomic
# SRR979792 metagenomic

# %%
samples_by_biome = {}
for n, (biome_name, count) in enumerate(all_biomes):
    print(f"getting: {biome_name} ({n + 1} of {len(all_biomes)})")
    samples_by_biome[biome_name] = get_samples_for_biome(biome_name)
    print(f"got: {len(samples_by_biome[biome_name])}")
# Out:
# getting: root:Environmental:Aquatic:Non-marine Saline and Alkaline:Hypersaline (1 of 196)
# working on page: 1 of 4
# working on page: 2 of 4
# working on page: 3 of 4
# working on page: 4 of 4
# got 4
# got: 4
# getting: root:Environmental:Terrestrial:Soil:Mine (2 of 196)
# working on page: 1 of 2
# working on page: 2 of 2
# got 2
# got: 2
# getting: root:Environmental:Terrestrial:Soil:Loam (3 of 196)
# working on page: 1 of 50
# working on page: 2 of 50
# working on page: 3 of 50
# working on page: 4 of 50
# working on page: 5 of 50
# working on page: 6 of 50
# working on page: 7 of 50
# working on page: 8 of 50
# working on page: 9 of 50
# working on page: 10 of 50
# working on page: 11 of 50
# working on page: 12 of 50
# working on page: 13 of 50
# working on page: 14 of 50
# working on page: 15 of 50
# working on page: 16 of 50
# working on page: 17 of 50
# working on page: 18 of 50
# working on page: 19 of 50
# working on page: 20 of 50
# working on page: 21 of 50
# working on page: 22 of 50
# working on page: 23 of 50
# working on page: 24 of 50
# working on page: 25 of 50
# working on page: 26 of 50
# working on page: 27 of 50
# working on page: 28 of 50
# working on page: 29 of 50
# working on page: 30 of 50
# working on page: 31 of 50
# working on page: 32 of 50
# working on page: 33 of 50
# working on page: 34 of 50
# working on page: 35 of 50
# working on page: 36 of 50
# working on page: 37 of 50
# working on page: 38 of 50
# working on page: 39 of 50
# working on page: 40 of 50
# working on page: 41 of 50
# working on page: 42 of 50
# working on page: 43 of 50
# working on page: 44 of 50
# working on page: 45 of 50
# working on page: 46 of 50
# working on page: 47 of 50
# working on page: 48 of 50
# working on page: 49 of 50
# working on page: 50 of 50
# got 50
# got: 50
# getting: root:Host-associated:Fish:Skin (4 of 196)
# working on page: 1 of 3
# working on page: 2 of 3
# working on page: 3 of 3
# got 3
# got: 3
# getting: root:Environmental:Aquatic:Freshwater:Groundwater:Acid Mine Drainage (5 of 196)
# working on page: 1 of 3
# working on page: 2 of 3
# working on page: 3 of 3
# got 3
# got: 3
# getting: root:Environmental:Terrestrial:Agricultural field (6 of 196)
# working on page: 1 of 3
# working on page: 2 of 3
# working on page: 3 of 3
# got 3
# got: 3
# getting: root:Engineered:Bioremediation:Persistent organic pollutants (POP) (7 of 196)
# working on page: 1 of 3
# working on page: 2 of 3
# working on page: 3 of 3
# got 3
# got: 3
# getting: root:Engineered:Lab enrichment:Defined media:Marine media (8 of 196)
# working on page: 1 of 3
# working on page: 2 of 3
# working on page: 3 of 3
# got 3
# got: 3
# getting: root:Engineered:Modeled:Simulated communities (DNA mixture) (9 of 196)
# working on page: 1 of 3
# working on page: 2 of 3
# working on page: 3 of 3
# got 3
# got: 3
# getting: root:Environmental:Aquatic:Freshwater:Wetlands:Marsh (10 of 196)
# working on page: 1 of 3
# working on page: 2 of 3
# working on page: 3 of 3
# got 3
# got: 3
# getting: root:Environmental:Terrestrial:Soil:Wetlands (11 of 196)
# working on page: 1 of 3
# working on page: 2 of 3
# working on page: 3 of 3
# got 3
# got: 3
# getting: root:Engineered:Lab enrichment:Defined media:Anaerobic media (12 of 196)
# working on page: 1 of 3
# working on page: 2 of 3
# working on page: 3 of 3
# got 3
# got: 3
# getting: root:Environmental (13 of 196)
# working on page: 1 of 3270
# working on page: 2 of 3270
# working on page: 3 of 3270
# working on page: 4 of 3270
# working on page: 5 of 3270
# working on page: 6 of 3270
# working on page: 7 of 3270
# working on page: 8 of 3270
# working on page: 9 of 3270
# working on page: 10 of 3270
# working on page: 11 of 3270
# working on page: 12 of 3270
# working on page: 13 of 3270
# working on page: 14 of 3270
# working on page: 15 of 3270
# working on page: 16 of 3270
# working on page: 17 of 3270
# working on page: 18 of 3270
# working on page: 19 of 3270
# working on page: 20 of 3270
# working on page: 21 of 3270
# working on page: 22 of 3270
# working on page: 23 of 3270
# working on page: 24 of 3270
# working on page: 25 of 3270
# working on page: 26 of 3270
# working on page: 27 of 3270
# working on page: 28 of 3270
# working on page: 29 of 3270
# working on page: 30 of 3270
# working on page: 31 of 3270
# working on page: 32 of 3270
# working on page: 33 of 3270
# working on page: 34 of 3270
# working on page: 35 of 3270
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[81], line 4
#       2 for n, (biome_name, count) in enumerate(all_biomes):
#       3     print(f"getting: {biome_name} ({n + 1} of {len(all_biomes)})")
# ----> 4     samples_by_biome[biome_name] = get_samples_for_biome(biome_name)
#       5     print(f"got: {len(samples_by_biome[biome_name])}")
#
# Cell In[63], line 10, in get_samples_for_biome(biome)
#       8 for page in range(1, num_pages + 1):
#       9     print(f'working on page: {page} of {num_pages}')
# ---> 10     r = requests.get(f"https://www.ebi.ac.uk/metagenomics/api/latest/{endpoint_name}/{biome}/samples?page={page}")
#      11     xx.append(r.json())
#      13 print(f'got {len(xx)}')
#
# File ~/miniforge3/envs/py311/lib/python3.11/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/miniforge3/envs/py311/lib/python3.11/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/miniforge3/envs/py311/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/miniforge3/envs/py311/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/miniforge3/envs/py311/lib/python3.11/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File ~/miniforge3/envs/py311/lib/python3.11/site-packages/urllib3/connectionpool.py:790, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     787 response_conn = conn if not release_conn else None
#     789 # Make the request on the HTTPConnection object
# --> 790 response = self._make_request(
#     791     conn,
#     792     method,
#     793     url,
#     794     timeout=timeout_obj,
#     795     body=body,
#     796     headers=headers,
#     797     chunked=chunked,
#     798     retries=retries,
#     799     response_conn=response_conn,
#     800     preload_content=preload_content,
#     801     decode_content=decode_content,
#     802     **response_kw,
#     803 )
#     805 # Everything went great!
#     806 clean_exit = True
#
# File ~/miniforge3/envs/py311/lib/python3.11/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/miniforge3/envs/py311/lib/python3.11/site-packages/urllib3/connection.py:461, in HTTPConnection.getresponse(self)
#     458 from .response import HTTPResponse
#     460 # Get the response from http.client.HTTPConnection
# --> 461 httplib_response = super().getresponse()
#     463 try:
#     464     assert_header_parsing(httplib_response.msg)
#
# File ~/miniforge3/envs/py311/lib/python3.11/http/client.py:1378, in HTTPConnection.getresponse(self)
#    1376 try:
#    1377     try:
# -> 1378         response.begin()
#    1379     except ConnectionError:
#    1380         self.close()
#
# File ~/miniforge3/envs/py311/lib/python3.11/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~/miniforge3/envs/py311/lib/python3.11/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~/miniforge3/envs/py311/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File ~/miniforge3/envs/py311/lib/python3.11/ssl.py:1311, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1307     if flags != 0:
#    1308         raise ValueError(
#    1309           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1310           self.__class__)
# -> 1311     return self.read(nbytes, buffer)
#    1312 else:
#    1313     return super().recv_into(buffer, nbytes, flags)
#
# File ~/miniforge3/envs/py311/lib/python3.11/ssl.py:1167, in SSLSocket.read(self, len, buffer)
#    1165 try:
#    1166     if buffer is not None:
# -> 1167         return self._sslobj.read(len, buffer)
#    1168     else:
#    1169         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
# TODO: dump to file!
